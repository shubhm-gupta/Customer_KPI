# %%
# import Algorithmia
# from Algorithmia.acl import ReadAcl, AclType

# nlp_directory = client.dir("data://abhalla/nlp_directory")
# # Create your data collection if it does not exist
# #nlp_directory.create()

# acl = nlp_directory.get_permissions()  # Acl object
# acl.read_acl == AclType.my_algos  # True

# # Update permissions to private
# nlp_directory.update_permissions(ReadAcl.private)
# nlp_directory.get_permissions().read_acl == AclType.private # True

# text_file= "data://abhalla/nlp_directory/test.txt"

# if client.file(text_file).exists() is False:
#     # Upload local file
#     client.file(text_file).putFile("C:\\Users\\akank\\Desktop\\Semester 2\\Big Data\\test.txt")
    
# if client.file(text_file).exists() is True:
#     localfile = client.file(text_file).getFile()

# if client.file(text_file).exists() is True:
#     input = client.file(text_file).getString()

# algo = client.algo('nlp/Summarizer/0.1.3')
# # Pass in input required by algorithm
# try:
#     # Get the summary result of your file's contents
#     print(algo.pipe(input).result)
# except Exception as error:
#     # Algorithm error if, for example, the input is not correctly formatted
#     print(error)
# Out:
# Sample and procedure
# Study 1
# Participants were recruited using the StudyResponse Project (The StudyResponse
# Project, n.d.). Creative activity, recovery experiences, and openness to
# experience were assessed in Wave 1, whereas performance-related outcomes were
# assessed in Wave 2. We obtained
# data of 92 active duty captains from the United States Air Force who were required to
# participate in an incentivized 6-week leadership development programme.

# %%
import re
import nltk
# Out:
# technology Hypothesis 1: Plants with commitment human resource systems will have better manufacturing performance than plants with control human resource systems. Hypothesis 2: Turnover will be higher in control human resource systems than in commitment human resource systems. THEORETICAL DEVELOPMENT AND HYPOTHESES Testing the strategic human resource perspective first requires catego- rizing organizations into a meaningful typology of human resource systems. Finally, Hypothesis 3 states that the negative relationship between turn- over and manufacturing performance will be higher in commitment human resource systems than in control systems. Further, research progress on the human resource strategy perspective depends critically on the development of conceptually and methodologi- cally sound measures of the human resource system construct. In contrast, commitment human resource systems shape desired employee behaviors and attitudes by forging psychological links between organizational and employee goals. In addition, the study has shown that identification of human resource systems promises to add significantly to understanding the relationship between turnover and organizational performance.

# %%
def summarize_article(article_text):
    article_text = re.sub(r'\[[0-9]*\]', ' ', article_text)  
    article_text = re.sub(r'\s+', ' ', article_text)  

    formatted_article_text = re.sub('[^a-zA-Z]', ' ', article_text )  
    formatted_article_text = re.sub(r'\s+', ' ', formatted_article_text)
    formatted_article_text = re.sub('-\n','', formatted_article_text)
    formatted_article_text = re.sub('\n',' ', formatted_article_text)
    
    sentence_list = nltk.sent_tokenize(article_text)  
    stopwords = nltk.corpus.stopwords.words('english')

    word_frequencies = {}  
    for word in nltk.word_tokenize(formatted_article_text):  
        if word not in stopwords:
            if word not in word_frequencies.keys():
                word_frequencies[word] = 1
            else:
                word_frequencies[word] += 1
    maximum_frequncy = max(word_frequencies.values())

    for word in word_frequencies.keys():  
        word_frequencies[word] = (word_frequencies[word]/maximum_frequncy)
    sentence_scores = {}  
    for sent in sentence_list:  
        for word in nltk.word_tokenize(sent.lower()):
            if word in word_frequencies.keys():
                if len(sent.split(' ')) < 30:
                    if sent not in sentence_scores.keys():
                        sentence_scores[sent] = word_frequencies[word]
                    else:
                        sentence_scores[sent] += word_frequencies[word]
    import heapq  
    summary_sentences = heapq.nlargest(7, sentence_scores, key=sentence_scores.get)

    summary = ' '.join(summary_sentences)  
    return summary

# %%
article_text_file = open("pdf2text_op/JOM-18-0621.txt","r",encoding="utf8")
article_text = article_text_file.read()

# %%
import glob
textFiles = glob.glob("pdf2text_op/*")

# %%
kpis = ["Net Promoter Score",
"Customer Retention Rate",
"Customer Profitability",
"Customer Lifetime Value",
"Customer Turnover Rate",
"Customer Engagement",
"SERVQUAL",
"Customer Complaint",
"Market Share",
"Market Growth Rate",
"Brand Equity",
"Conversion Rate",
"Customer Online Engagement",
"Online Share of Voice",
"Social Networking Footprint",
"Klout Score",
"Corporate Reputation",
"DIFOT Rate",
"Customer Satisfaction",
"customer experience",
"customer loyalty",
"brand attributes",
"customer support",
"first contact resolution",
"customer attraction",
"customer callback",
"customer focus",
"service level",
"customer effort score",
"Support Cost",
"average response time",
"Complaint Escalation Rate",
"customer integration"]

# %%
def find_all(a_string, sub):
    result = []
    k = 0
    while k < len(a_string):
        k = a_string.find(sub, k)
        if k == -1:
            return result
        else:
            result.append(k)
            k += 1 #change to k += len(sub) to not search overlapping results
    return result

# %%
count = 0
kpi_text={}
for textFile in textFiles:
    article_text_file = open(textFile,"r",encoding="utf8")
    article_text = article_text_file.read()

    for kpi in kpis:
        if kpi.lower() in article_text.lower():
            if kpi_text.get(kpi.lower()) :
                kpi_text[kpi.lower()].append([textFile,find_all(article_text.lower(),kpi.lower())])
            else:
                kpi_text[kpi.lower()] = [[textFile,find_all(article_text.lower(),kpi.lower())]]

# %%
kpi_text.keys()
# Out:
# dict_keys(['customer complaint', 'customer satisfaction', 'customer focus', 'market share', 'corporate reputation', 'customer loyalty', 'customer integration', 'brand equity', 'service level', 'market growth rate', 'servqual', 'customer engagement', 'customer lifetime value', 'customer support', 'customer experience', 'customer retention rate'])

# %%
kpi_text
# Out:
# {'customer complaint': [['pdf2text_op\\a098ijqs.txt', [99863]],
#   ['pdf2text_op\\ad00jom.txt', [10242, 90673, 94437]],
#   ['pdf2text_op\\bc11amj.txt', [38972, 108752]],
#   ['pdf2text_op\\breb08jom.txt', [61504, 62257]],
#   ['pdf2text_op\\cl10pp.txt', [112973]],
#   ['pdf2text_op\\g00dissertation.txt', [125906]],
#   ['pdf2text_op\\h01dissertation.txt', [189969]],
#   ['pdf2text_op\\hf96jom.txt', [88577, 90163, 90536]],
#   ['pdf2text_op\\k99dissertation.txt', [65205]],
#   ['pdf2text_op\\kki08smq.txt', [13437]],
#   ['pdf2text_op\\lhwh15ijlm.txt', [76924]],
#   ['pdf2text_op\\ltg13jcp.txt', [21125]],
#   ['pdf2text_op\\nmp05jom.txt', [25375]],
#   ['pdf2text_op\\st99jom.txt', [50223]],
#   ['pdf2text_op\\wwy13jbbm.txt', [28037]],
#   ['pdf2text_op\\y07tqm.txt', [8740, 9190]],
#   ['pdf2text_op\\y07tqmbe.txt', [8740, 9190]],
#   ['pdf2text_op\\ys03jbr.txt', [63575]]],
#  'customer satisfaction': [['pdf2text_op\\a098ijqs.txt',
#    [28415, 99819, 99948]],
#   ['pdf2text_op\\a09jhr.txt',
#    [1974,
#     2356,
#     2518,
#     2571,
#     9487,
#     12665,
#     12751,
#     12962,
#     16290,
#     17536,
#     19985,
#     21049,
#     24849,
#     26393,
#     26489,
#     30406,
#     33023,
#     33669,
#     33846,
#     33896,
#     34263,
#     34338,
#     34481,
#     34854,
#     34954,
#     35438,
#     35531,
#     41501,
#     41919,
#     45301,
#     47374,
#     48754,
#     49107,
#     49134,
#     49368]],
#   ['pdf2text_op\\ad00jom.txt', [16165]],
#   ['pdf2text_op\\adg08hrm.txt', [29592, 70304]],
#   ['pdf2text_op\\amm15ijpe.txt',
#    [1187,
#     12012,
#     28694,
#     32749,
#     36841,
#     43387,
#     47940,
#     48238,
#     50560,
#     52581,
#     52728,
#     52999,
#     53110,
#     53803,
#     53863,
#     54122,
#     54263,
#     54681,
#     55367,
#     56654,
#     57807,
#     58773,
#     59761,
#     60231,
#     61053,
#     61193,
#     62187,
#     62305,
#     65612,
#     65729,
#     67614,
#     68109,
#     68269,
#     68596,
#     68695,
#     69126,
#     70609,
#     72702,
#     74583,
#     75250,
#     75578,
#     75946,
#     76188,
#     78880,
#     86202,
#     101478]],
#   ['pdf2text_op\\ay14ijbs.txt', [7284, 21382, 61244]],
#   ['pdf2text_op\\azw06meq.txt',
#    [3340,
#     4509,
#     10465,
#     10840,
#     23680,
#     36781,
#     40369,
#     42836,
#     42932,
#     45363,
#     45475,
#     46259,
#     51156,
#     51522,
#     59996]],
#   ['pdf2text_op\\azw06meqij.txt',
#    [534,
#     1703,
#     7489,
#     7864,
#     20364,
#     33210,
#     36628,
#     39010,
#     39106,
#     41452,
#     41564,
#     42348,
#     47075,
#     47441,
#     55745]],
#   ['pdf2text_op\\b94dissertation.txt', [205198]],
#   ['pdf2text_op\\b99dissertation.txt', [34938]],
#   ['pdf2text_op\\bc11amj.txt',
#    [7696,
#     28148,
#     31249,
#     37596,
#     38066,
#     38118,
#     47305,
#     59135,
#     59445,
#     59895,
#     60027,
#     60386,
#     60540,
#     60672,
#     60857,
#     61014,
#     61202,
#     61485,
#     61642,
#     65795,
#     69980,
#     70426,
#     72871,
#     104805,
#     108207,
#     108307,
#     112107]],
#   ['pdf2text_op\\bc15apjm.txt', [18079, 26301, 36744, 65514, 66629, 75654]],
#   ['pdf2text_op\\bjn05jbv.txt', [40487]],
#   ['pdf2text_op\\bnk00jbr.txt',
#    [243,
#     727,
#     1091,
#     1197,
#     1383,
#     2434,
#     2500,
#     2580,
#     2791,
#     4298,
#     4889,
#     5407,
#     6053,
#     6187,
#     6239,
#     6332,
#     7139,
#     7246,
#     7589,
#     8263,
#     8633,
#     8738,
#     8858,
#     8976,
#     9222,
#     9401,
#     10518,
#     12512,
#     12585,
#     13629,
#     13797,
#     14396,
#     14722,
#     15074,
#     16355,
#     16430,
#     17134,
#     17296,
#     17649,
#     20894,
#     21855,
#     23148,
#     23193,
#     24136,
#     24561,
#     25539,
#     25743,
#     26152,
#     26548,
#     26667,
#     26920,
#     27188,
#     27318,
#     27830,
#     28322,
#     28642,
#     28764,
#     29276,
#     29371,
#     29521,
#     29825,
#     29912,
#     30000,
#     30090,
#     30466,
#     30589,
#     30661,
#     30737,
#     31250,
#     31451,
#     31632,
#     32170,
#     32360,
#     32692,
#     32935,
#     33126,
#     33416,
#     33468,
#     33571,
#     33848,
#     34177,
#     34724,
#     34937,
#     35119,
#     35182,
#     35535,
#     36176,
#     36337,
#     36698,
#     36857,
#     37157,
#     37343,
#     37434,
#     37866,
#     37925,
#     37989,
#     38174,
#     38244,
#     38643,
#     39156,
#     39342,
#     41262,
#     41913,
#     42171,
#     42267,
#     43050,
#     43414,
#     43545,
#     43604,
#     43809,
#     44198,
#     44830,
#     46346,
#     46471,
#     46679,
#     47143,
#     48686,
#     48889,
#     50309,
#     52577,
#     53085,
#     55248]],
#   ['pdf2text_op\\breb08jom.txt', [62167, 85820, 104202]],
#   ['pdf2text_op\\brm11jbe.txt', [1514, 10754, 16155, 51872]],
#   ['pdf2text_op\\bw11jbr.txt', [1480, 30267]],
#   ['pdf2text_op\\bwb11jbr.txt', [11288, 41522]],
#   ['pdf2text_op\\c03dissertation.txt',
#    [70251, 71488, 72984, 73264, 156877, 164613, 165969]],
#   ['pdf2text_op\\c09qq.txt', [32283]],
#   ['pdf2text_op\\c12dissertation.txt', [49474, 51485]],
#   ['pdf2text_op\\cakm09josr.txt',
#    [2558,
#     4561,
#     5354,
#     5615,
#     6819,
#     8912,
#     13641,
#     19935,
#     20449,
#     20801,
#     23009,
#     23515,
#     24097,
#     24339,
#     24474,
#     24760,
#     24948,
#     25035,
#     25180,
#     25376,
#     25486,
#     32920,
#     33131,
#     33822,
#     34184,
#     34321,
#     44174,
#     44250,
#     44431,
#     44707,
#     45685,
#     46252,
#     46279,
#     46581,
#     46732,
#     46970,
#     53774,
#     56935,
#     57598,
#     58094,
#     58390,
#     62558,
#     81743,
#     83776]],
#   ['pdf2text_op\\cb07imm.txt', [12838, 42356, 42408, 50076, 52244]],
#   ['pdf2text_op\\cc12jbe.txt', [66904]],
#   ['pdf2text_op\\cclc11treltr.txt', [61743]],
#   ['pdf2text_op\\cct10lodj.txt', [47605]],
#   ['pdf2text_op\\ce10jbr.txt', [35889, 37829, 41623, 45082]],
#   ['pdf2text_op\\ce98jom.txt',
#    [133,
#     863,
#     926,
#     1092,
#     1486,
#     2863,
#     4066,
#     4233,
#     6134,
#     6640,
#     7094,
#     13592,
#     13799,
#     14210,
#     14826,
#     14998,
#     15154,
#     15830,
#     16963,
#     17237,
#     17414,
#     17717,
#     18426,
#     18610,
#     19235,
#     19388,
#     23676,
#     24087,
#     26778,
#     27669,
#     27709,
#     29997,
#     30480,
#     31008,
#     32952,
#     33258,
#     33307,
#     33699,
#     35201,
#     35681,
#     36813,
#     38067,
#     39136,
#     40151,
#     43713,
#     43765,
#     44491,
#     44992,
#     47757,
#     48548,
#     51119,
#     53730,
#     53984,
#     54495,
#     55753,
#     56246,
#     57665,
#     58779,
#     62365,
#     64177,
#     64911]],
#   ['pdf2text_op\\cgl09jom.txt', [73423]],
#   ['pdf2text_op\\ck99smj.txt', [48613]],
#   ['pdf2text_op\\ckc12ijopm.txt', [25731]],
#   ['pdf2text_op\\cl10pp.txt', [31075, 105266, 106070, 108101]],
#   ['pdf2text_op\\clrv04ar.txt', [15270, 85828]],
#   ['pdf2text_op\\cm06jom.txt', [22835]],
#   ['pdf2text_op\\ct05crr.txt', [4291, 4714, 5250, 46127]],
#   ['pdf2text_op\\cvd00ds.txt', [11588, 52898]],
#   ['pdf2text_op\\cydl15ijpe.txt', [2606]],
#   ['pdf2text_op\\dga15ijpe.txt', [15439, 19912, 26001, 42856, 50524, 54739]],
#   ['pdf2text_op\\dkw07jom.txt', [23506]],
#   ['pdf2text_op\\dv04hrmj.txt', [85353]],
#   ['pdf2text_op\\dvdunpublishedmanuscript.txt',
#    [61,
#     1027,
#     1885,
#     1976,
#     2630,
#     5921,
#     6261,
#     6340,
#     7939,
#     8197,
#     8830,
#     9770,
#     11172,
#     53182,
#     56012,
#     56085,
#     57281,
#     92221,
#     92795,
#     93077,
#     93674,
#     100130,
#     103267,
#     105076,
#     105738,
#     106673,
#     110549,
#     110773,
#     111565,
#     111932,
#     112589,
#     115679,
#     128975,
#     129754,
#     130365,
#     131023,
#     131615,
#     136025,
#     136611,
#     142115,
#     143790,
#     143976,
#     279142,
#     279318,
#     279895,
#     283012,
#     293633,
#     293984,
#     295437,
#     297496,
#     299921,
#     300045,
#     301160,
#     302738,
#     302922,
#     303788,
#     309944,
#     328032,
#     331719,
#     331986,
#     332339,
#     335200,
#     336126,
#     336924,
#     337691,
#     346989,
#     348300,
#     349301,
#     349518,
#     349865,
#     350600,
#     350927,
#     351283,
#     357024,
#     359361,
#     363998,
#     366474,
#     377004,
#     383221,
#     383574]],
#   ['pdf2text_op\\ecl99ccaij.txt', [23095]],
#   ['pdf2text_op\\fcwz15jcp.txt', [54494]],
#   ['pdf2text_op\\ff98ijpe.txt',
#    [83,
#     938,
#     1444,
#     3242,
#     4809,
#     15405,
#     16084,
#     18034,
#     28348,
#     29536,
#     39863,
#     45723,
#     54560,
#     58498,
#     60524,
#     61025,
#     63821,
#     65307,
#     67730]],
#   ['pdf2text_op\\fhz10jom.txt', [18517, 27102, 64134, 75525]],
#   ['pdf2text_op\\fsdm05xxx.txt', [43731]],
#   ['pdf2text_op\\fswm05ijhrm.txt', [43731]],
#   ['pdf2text_op\\g00dissertation.txt',
#    [5286,
#     7860,
#     10209,
#     12605,
#     13532,
#     13754,
#     16578,
#     16703,
#     17787,
#     18376,
#     21269,
#     22520,
#     27408,
#     28452,
#     32497,
#     37971,
#     48448,
#     62604,
#     64083,
#     64241,
#     66206,
#     66423,
#     69008,
#     75181,
#     75680,
#     76163,
#     77010,
#     77814,
#     78404,
#     78682,
#     79101,
#     79380,
#     79575,
#     80447,
#     80510,
#     80598,
#     80709,
#     81022,
#     81120,
#     81674,
#     82784,
#     84480,
#     85765,
#     86724,
#     86785,
#     88033,
#     88174,
#     88464,
#     90375,
#     95085,
#     95251,
#     95638,
#     96649,
#     97073,
#     97359,
#     98719,
#     99988,
#     100739,
#     106535,
#     124625,
#     126306,
#     127767,
#     135645,
#     141454,
#     141831,
#     142028,
#     143766,
#     145177,
#     147020,
#     155406,
#     160818,
#     167820,
#     170091,
#     170352,
#     174203,
#     174567,
#     174915,
#     177123,
#     177498,
#     177950]],
#   ['pdf2text_op\\gi03pp.txt',
#    [2905,
#     5290,
#     6247,
#     12108,
#     17364,
#     17388,
#     18536,
#     29345,
#     32162,
#     32891,
#     39973,
#     41131,
#     41261,
#     41905,
#     42877,
#     44053,
#     44124,
#     44350,
#     44895,
#     45507,
#     45662,
#     46467,
#     56468,
#     58236]],
#   ['pdf2text_op\\gwm11pp.txt', [47926]],
#   ['pdf2text_op\\gzw06meq.txt',
#    [3244,
#     4413,
#     10351,
#     10726,
#     23530,
#     36604,
#     40174,
#     42632,
#     42728,
#     45150,
#     45262,
#     46046,
#     50925,
#     51291,
#     59747]],
#   ['pdf2text_op\\h05dissertation.txt', [12045, 141243]],
#   ['pdf2text_op\\h07crr.txt', [54468]],
#   ['pdf2text_op\\hd10jpim.txt', [39564]],
#   ['pdf2text_op\\hf96jom.txt', [26303, 27030, 28884, 106770]],
#   ['pdf2text_op\\hjr12ppc.txt', [5059, 16746, 29006]],
#   ['pdf2text_op\\hlsc14ijpe.txt', [63436, 70719]],
#   ['pdf2text_op\\hpcl09ijopm.txt', [20331]],
#   ['pdf2text_op\\hs04jams.txt',
#    [185,
#     471,
#     738,
#     1088,
#     1184,
#     1443,
#     2087,
#     2370,
#     2780,
#     3225,
#     3720,
#     5350,
#     5912,
#     6477,
#     7453,
#     8885,
#     9750,
#     10178,
#     10577,
#     10718,
#     10875,
#     11202,
#     11284,
#     11579,
#     12050,
#     12208,
#     12531,
#     12774,
#     13406,
#     13688,
#     13887,
#     14141,
#     14365,
#     14621,
#     15460,
#     18476,
#     18985,
#     19401,
#     19638,
#     20992,
#     21230,
#     22461,
#     24838,
#     24945,
#     25153,
#     28081,
#     29037,
#     30286,
#     34595,
#     34926,
#     37157,
#     37728,
#     39314,
#     39440,
#     39737,
#     39988,
#     40265,
#     40468,
#     40624,
#     41847,
#     42169,
#     42701,
#     43127,
#     43294,
#     44942,
#     45090,
#     45404,
#     46632,
#     46855,
#     47397,
#     48165,
#     49237,
#     50459,
#     50695,
#     50818,
#     51164,
#     51411,
#     52387,
#     53937,
#     54119,
#     54653,
#     55598,
#     60213,
#     60478,
#     60580,
#     65087,
#     66830,
#     67430,
#     70566,
#     70761,
#     73901]],
#   ['pdf2text_op\\hss08imm.txt', [46363, 63935, 67077]],
#   ['pdf2text_op\\hy14mrr.txt', [5223, 20752, 60562]],
#   ['pdf2text_op\\j07dissertation.txt', [63760]],
#   ['pdf2text_op\\j11sij.txt', [30213]],
#   ['pdf2text_op\\jdrv13ijpr.txt', [24807, 33028, 71273]],
#   ['pdf2text_op\\jg05jbr.txt', [17976, 28837]],
#   ['pdf2text_op\\jk16jbe.txt', [28109, 36238, 48687, 66616]],
#   ['pdf2text_op\\JOM-18-0621.txt', [38406]],
#   ['pdf2text_op\\jpd03jbr.txt',
#    [1927, 9932, 35179, 35566, 38148, 68256, 79523]],
#   ['pdf2text_op\\jxn11ijpr.txt', [3259]],
#   ['pdf2text_op\\jy11bjir.txt', [14994]],
#   ['pdf2text_op\\k03jom.txt',
#    [11539,
#     16808,
#     17585,
#     18061,
#     18704,
#     23030,
#     24228,
#     24781,
#     24845,
#     24952,
#     25760,
#     25961,
#     26352,
#     26422,
#     27918,
#     28357,
#     28380,
#     103345,
#     107698,
#     107862]],
#   ['pdf2text_op\\k97errj.txt', [19357]],
#   ['pdf2text_op\\k99dissertation.txt',
#    [5355,
#     22346,
#     26080,
#     27156,
#     27326,
#     27444,
#     27613,
#     28957,
#     30413,
#     30481,
#     30659,
#     30961,
#     33328,
#     38138,
#     38265,
#     41687,
#     42279,
#     43720,
#     46434,
#     47064,
#     50164,
#     50341,
#     51091,
#     51395,
#     54008,
#     70724,
#     71362,
#     71526,
#     73470,
#     74802,
#     88493,
#     123525,
#     233068,
#     236295,
#     236790,
#     259920,
#     261634,
#     261839,
#     269244,
#     270527,
#     273450,
#     296002,
#     298374,
#     299281,
#     299384,
#     305285,
#     305738,
#     308248,
#     308761,
#     308864]],
#   ['pdf2text_op\\kcmw13jepm.txt', [23828, 80002]],
#   ['pdf2text_op\\kx09imm.txt', [6784, 61591]],
#   ['pdf2text_op\\lchp09ijpr.txt', [19332, 47776]],
#   ['pdf2text_op\\lcy12ijebm.txt', [54961]],
#   ['pdf2text_op\\lk11ijhm.txt',
#    [1307, 5017, 7146, 7870, 36428, 39518, 48104, 50537, 54594]],
#   ['pdf2text_op\\lkhl10ijpr.txt', [59009]],
#   ['pdf2text_op\\lnaa08job.txt', [25268, 30435, 79411]],
#   ['pdf2text_op\\lpaf13jcp.txt',
#    [6015,
#     11409,
#     17061,
#     17307,
#     17738,
#     21486,
#     35552,
#     39300,
#     40693,
#     43034,
#     44824,
#     47282,
#     58565]],
#   ['pdf2text_op\\lwlm14amj.txt', [46102, 60079, 83068]],
#   ['pdf2text_op\\lww13ijpe.txt', [35989]],
#   ['pdf2text_op\\m94dissertation.txt',
#    [1668,
#     24609,
#     24785,
#     24910,
#     27926,
#     28231,
#     28366,
#     30425,
#     49824,
#     55931,
#     56110,
#     56533,
#     83514,
#     83761,
#     120933,
#     121117,
#     124532,
#     125583,
#     125607,
#     134625,
#     170077,
#     170253,
#     170373,
#     213022,
#     213156,
#     219016,
#     245711,
#     245911,
#     246144,
#     261949]],
#   ['pdf2text_op\\mb05ejm.txt', [20600, 38176, 38775, 40703, 40780]],
#   ['pdf2text_op\\mdg00ijpr.txt', [49182]],
#   ['pdf2text_op\\mmr01jap.txt', [19611]],
#   ['pdf2text_op\\mn99jit.txt',
#    [10792,
#     12307,
#     13546,
#     13625,
#     15443,
#     15768,
#     31653,
#     33583,
#     34133,
#     34254,
#     37696,
#     37736]],
#   ['pdf2text_op\\ms09jom.txt', [12985]],
#   ['pdf2text_op\\ms10jbe.txt', [15191, 82982, 104100]],
#   ['pdf2text_op\\myb12hrmj.txt', [50936, 56813]],
#   ['pdf2text_op\\ng10crr.txt', [41834]],
#   ['pdf2text_op\\nl01jrcs.txt', [37770, 41330, 42804, 45374, 47116, 47758]],
#   ['pdf2text_op\\nls08pp.txt',
#    [246,
#     1086,
#     2240,
#     3139,
#     5198,
#     5710,
#     12792,
#     13834,
#     36892,
#     40248,
#     40518,
#     41414,
#     42694,
#     42929,
#     43231,
#     43965,
#     45439,
#     62927,
#     62961,
#     63420,
#     63529,
#     66659,
#     67732,
#     70810,
#     71778,
#     89780,
#     98332,
#     98411,
#     103743,
#     104583,
#     122022]],
#   ['pdf2text_op\\nmp05jom.txt',
#    [17378, 27503, 36780, 39355, 40481, 42937, 46445, 46477, 46515, 46538]],
#   ['pdf2text_op\\nsrsa13apjml.txt', [14793, 56671]],
#   ['pdf2text_op\\ocm11jbe.txt', [32070]],
#   ['pdf2text_op\\odmm12jbl.txt', [23002]],
#   ['pdf2text_op\\pl06jap.txt', [7006, 52747]],
#   ['pdf2text_op\\ps03ijqrm.txt', [82202]],
#   ['pdf2text_op\\pwr09amj.txt', [29201, 38889]],
#   ['pdf2text_op\\rbm09jbe.txt', [33654]],
#   ['pdf2text_op\\rffa98jom.txt',
#    [8405,
#     9223,
#     10075,
#     11793,
#     26439,
#     27581,
#     27658,
#     30374,
#     32582,
#     32625,
#     33260,
#     33869,
#     38102,
#     40110,
#     40168,
#     40311,
#     40402,
#     40600,
#     60662]],
#   ['pdf2text_op\\rsj86pp.txt',
#    [411,
#     735,
#     2052,
#     10325,
#     10734,
#     11358,
#     13574,
#     22743,
#     22773,
#     24050,
#     35145,
#     39502,
#     45414,
#     50627,
#     54547,
#     63624,
#     65677,
#     65969]],
#   ['pdf2text_op\\rsss01jom.txt',
#    [107,
#     574,
#     769,
#     4537,
#     6673,
#     10110,
#     17169,
#     18166,
#     35574,
#     35730,
#     38160,
#     38419,
#     39772,
#     39885,
#     40047,
#     40246,
#     41408,
#     41734,
#     42388,
#     44880,
#     45119,
#     45481,
#     49086,
#     59508,
#     61097]],
#   ['pdf2text_op\\rwss10jpbm.txt', [6489]],
#   ['pdf2text_op\\s01dissertation.txt',
#    [1793,
#     3178,
#     4687,
#     5002,
#     5292,
#     7745,
#     11342,
#     11468,
#     22772,
#     22922,
#     23808,
#     24083,
#     24789,
#     25091,
#     25360,
#     25603,
#     41005,
#     41168,
#     41368,
#     41492,
#     43568,
#     44375,
#     45256,
#     47649,
#     48086,
#     48139,
#     48983,
#     49748,
#     49812,
#     50252,
#     50546,
#     50751,
#     50857,
#     54426,
#     54849,
#     57061,
#     58120,
#     60271,
#     62002,
#     62137,
#     64958,
#     67998,
#     68341,
#     69940,
#     70339,
#     70559,
#     77802,
#     78670,
#     79066,
#     79257,
#     79406,
#     79561,
#     79836,
#     80142,
#     80256,
#     81933,
#     82023,
#     82341,
#     82490,
#     82637,
#     82843,
#     83060,
#     84102,
#     84240,
#     87324,
#     92945,
#     95815,
#     98090,
#     98220,
#     99100,
#     99217,
#     101910,
#     102305,
#     102503,
#     104624,
#     111373,
#     111471,
#     111809,
#     112211,
#     112386,
#     113619,
#     113760,
#     113953,
#     115033,
#     115292,
#     115405,
#     116065,
#     116382,
#     116500,
#     116734,
#     117177,
#     117583,
#     117765,
#     118148,
#     118451,
#     118873,
#     119296,
#     119754,
#     120738,
#     120826,
#     121199,
#     121279,
#     122139,
#     122508,
#     122802,
#     123740,
#     124435,
#     124587,
#     130056,
#     130111,
#     130246,
#     130335,
#     130559,
#     130644,
#     130793,
#     131104,
#     131510,
#     134253,
#     134485,
#     134573,
#     134831,
#     135911,
#     136201,
#     136339,
#     136467,
#     137940,
#     139102,
#     139701,
#     143959,
#     144163,
#     146487,
#     146685,
#     146786,
#     147801,
#     150648,
#     155491,
#     156678,
#     156947,
#     165350,
#     165807,
#     165860,
#     167201,
#     167596,
#     169823,
#     185713,
#     193957]],
#   ['pdf2text_op\\s08dissertation.txt', [561023]],
#   ['pdf2text_op\\s98dissertation.txt', [173679]],
#   ['pdf2text_op\\sab07md.txt', [23334]],
#   ['pdf2text_op\\sbj04apair.txt',
#    [4933,
#     7174,
#     10780,
#     15469,
#     16292,
#     16679,
#     23147,
#     24507,
#     28245,
#     28294,
#     29159,
#     36611,
#     36861,
#     47835]],
#   ['pdf2text_op\\sc00ijsim.txt',
#    [1224,
#     2188,
#     3800,
#     4126,
#     4413,
#     5826,
#     6232,
#     6712,
#     7199,
#     9247,
#     10636,
#     13376,
#     14851,
#     17889,
#     18313,
#     18335,
#     19014,
#     19127,
#     26667,
#     26777,
#     27135,
#     27837,
#     28031,
#     28552,
#     28756,
#     31344,
#     33330,
#     33903,
#     36545,
#     38100,
#     40341,
#     40595,
#     40645,
#     40692,
#     40730,
#     51646,
#     52106,
#     53480,
#     54544,
#     58688,
#     64123]],
#   ['pdf2text_op\\sdmdff06jms.txt', [48935]],
#   ['pdf2text_op\\se00asq.txt', [78921]],
#   ['pdf2text_op\\sh11jop.txt',
#    [17,
#     827,
#     1023,
#     6489,
#     7074,
#     10446,
#     10473,
#     11611,
#     15416,
#     15440,
#     15862,
#     17217,
#     17983,
#     18419,
#     18763,
#     18978,
#     20121,
#     20180,
#     20328,
#     21863,
#     22952,
#     24463,
#     24598,
#     25695,
#     25918,
#     26273,
#     26450,
#     26781,
#     27058,
#     31236,
#     33371,
#     39155,
#     41944,
#     43603,
#     46637,
#     46781]],
#   ['pdf2text_op\\slg07isr.txt', [18110]],
#   ['pdf2text_op\\snk05dsj.txt', [31463, 65261]],
#   ['pdf2text_op\\snw07jom.txt',
#    [17404,
#     27699,
#     27812,
#     36758,
#     37555,
#     41233,
#     44531,
#     45316,
#     45454,
#     46534,
#     46768,
#     52203,
#     54317,
#     55082,
#     56489,
#     57303,
#     60926,
#     62646,
#     62792]],
#   ['pdf2text_op\\st99jom.txt', [15729, 50373]],
#   ['pdf2text_op\\sz13jpim.txt', [65617, 71682, 74895, 75074]],
#   ['pdf2text_op\\sz91hrp.txt', [42]],
#   ['pdf2text_op\\vp04job.txt', [64869]],
#   ['pdf2text_op\\vt06mr.txt', [21960, 25173, 36264]],
#   ['pdf2text_op\\w05pp.txt', [20139, 20289, 20576, 21056, 100435]],
#   ['pdf2text_op\\w10misq.txt', [42444, 75802]],
#   ['pdf2text_op\\wb07jams.txt',
#    [1144,
#     12799,
#     18227,
#     46148,
#     50877,
#     52222,
#     54057,
#     54575,
#     54945,
#     55600,
#     55731,
#     56913,
#     68673,
#     70556,
#     82848,
#     83429]],
#   ['pdf2text_op\\wbs09ajbr.txt', [10071]],
#   ['pdf2text_op\\wdw06jsm.txt',
#    [416,
#     799,
#     892,
#     1458,
#     2216,
#     5379,
#     6158,
#     6500,
#     6689,
#     9133,
#     9306,
#     10607,
#     12684,
#     13055,
#     14145,
#     14481,
#     14662,
#     14882,
#     14972,
#     15076,
#     16227,
#     17113,
#     19908,
#     20127,
#     20261,
#     20584,
#     21653,
#     21879,
#     22140,
#     22197,
#     22596,
#     24304,
#     24336,
#     25349,
#     25519,
#     26463,
#     26939,
#     27210,
#     27446,
#     27515,
#     27772,
#     27895,
#     28185,
#     29860,
#     30513,
#     31894,
#     32616,
#     33276,
#     34974,
#     36167,
#     43091,
#     44456,
#     46118,
#     46900,
#     47013,
#     47203,
#     47439,
#     47508,
#     47698,
#     47821,
#     47857,
#     47957,
#     48130]],
#   ['pdf2text_op\\wew07jbr.txt',
#    [68,
#     967,
#     1207,
#     1411,
#     1693,
#     1886,
#     2833,
#     2864,
#     3710,
#     3825,
#     4820,
#     4966,
#     5253,
#     5786,
#     6103,
#     6827,
#     8137,
#     8307,
#     8790,
#     10832,
#     11707,
#     13175,
#     13397,
#     14454,
#     15399,
#     15641,
#     15921,
#     16215,
#     16547,
#     18587,
#     19693,
#     21638,
#     21798,
#     22279,
#     22649,
#     22729,
#     22854,
#     23189,
#     24447,
#     24501,
#     24674,
#     25278,
#     25586,
#     26028,
#     26235,
#     26543,
#     28019,
#     28938,
#     29087,
#     29502,
#     30556,
#     30762,
#     31190,
#     31524,
#     33317,
#     33666,
#     35096,
#     36411,
#     36627,
#     39918]],
#   ['pdf2text_op\\whpd10jbe.txt', [84768]],
#   ['pdf2text_op\\wlsl14bse.txt', [21097]],
#   ['pdf2text_op\\wm13jpssm.txt', [17071, 77809]],
#   ['pdf2text_op\\wmjb09bjm.txt',
#    [1144,
#     23066,
#     23986,
#     24708,
#     32493,
#     33467,
#     37794,
#     41077,
#     43786,
#     44056,
#     46967,
#     47965,
#     52527,
#     52780,
#     53123,
#     61135,
#     64720]],
#   ['pdf2text_op\\wwy13jbbm.txt', [16557, 26848]],
#   ['pdf2text_op\\x13bse.txt', [55007]],
#   ['pdf2text_op\\xp11jsm.txt', [15087, 41512]],
#   ['pdf2text_op\\y07tqm.txt',
#    [122,
#     291,
#     372,
#     451,
#     858,
#     1141,
#     1428,
#     1502,
#     1866,
#     2079,
#     2711,
#     3462,
#     3623,
#     3707,
#     3839,
#     4110,
#     4194,
#     4391,
#     4728,
#     5060,
#     5597,
#     5737,
#     6208,
#     6583,
#     6762,
#     6809,
#     6894,
#     6947,
#     7537,
#     7648,
#     7802,
#     7877,
#     8216,
#     8674,
#     9093,
#     9517,
#     9594,
#     10378,
#     10586,
#     10648,
#     10791,
#     11508,
#     13260,
#     13570,
#     13761,
#     14610,
#     14687,
#     15352,
#     15563,
#     15756,
#     17408,
#     17553,
#     17649,
#     18128,
#     18242,
#     18381,
#     18425,
#     18904,
#     18981,
#     19049,
#     19119,
#     19193,
#     19265,
#     19329,
#     19686,
#     19741,
#     20072,
#     20245,
#     21171,
#     21454,
#     22109,
#     22211,
#     22365,
#     22725,
#     22811,
#     23196,
#     23266,
#     23449,
#     24064,
#     24106,
#     24249,
#     24442,
#     24528,
#     25037,
#     25339,
#     25786,
#     25974,
#     26032,
#     27955,
#     28160,
#     28236,
#     28447,
#     28507,
#     28868,
#     29187,
#     29286,
#     29383,
#     29528,
#     29611,
#     31551,
#     31912,
#     32101,
#     32194,
#     32315,
#     32515,
#     32622,
#     32730,
#     35927,
#     36010,
#     38210,
#     39003,
#     39155,
#     39204,
#     40296,
#     40554,
#     40682,
#     40811,
#     41334,
#     42268,
#     42331,
#     42488,
#     42592,
#     42739,
#     43393,
#     43562,
#     43850,
#     44614,
#     45419]],
#   ['pdf2text_op\\y07tqmbe.txt',
#    [122,
#     291,
#     372,
#     451,
#     858,
#     1141,
#     1428,
#     1502,
#     1866,
#     2079,
#     2711,
#     3462,
#     3623,
#     3707,
#     3839,
#     4110,
#     4194,
#     4391,
#     4728,
#     5060,
#     5597,
#     5737,
#     6208,
#     6583,
#     6762,
#     6809,
#     6894,
#     6947,
#     7537,
#     7648,
#     7802,
#     7877,
#     8216,
#     8674,
#     9093,
#     9517,
#     9594,
#     10378,
#     10586,
#     10648,
#     10791,
#     11508,
#     13260,
#     13570,
#     13761,
#     14610,
#     14687,
#     15352,
#     15563,
#     15756,
#     17408,
#     17553,
#     17649,
#     18128,
#     18242,
#     18381,
#     18425,
#     18904,
#     18981,
#     19049,
#     19119,
#     19193,
#     19265,
#     19329,
#     19686,
#     19741,
#     20072,
#     20245,
#     21171,
#     21454,
#     22109,
#     22211,
#     22365,
#     22725,
#     22811,
#     23196,
#     23266,
#     23449,
#     24064,
#     24106,
#     24249,
#     24442,
#     24528,
#     25037,
#     25339,
#     25786,
#     25974,
#     26032,
#     27955,
#     28160,
#     28236,
#     28447,
#     28507,
#     28868,
#     29187,
#     29286,
#     29383,
#     29528,
#     29611,
#     31551,
#     31912,
#     32101,
#     32194,
#     32315,
#     32515,
#     32622,
#     32730,
#     35927,
#     36010,
#     38210,
#     39003,
#     39155,
#     39204,
#     40296,
#     40554,
#     40682,
#     40811,
#     41334,
#     42268,
#     42331,
#     42488,
#     42592,
#     42739,
#     43393,
#     43562,
#     43850,
#     44614,
#     45419]],
#   ['pdf2text_op\\yjse13ijpe.txt',
#    [213,
#     742,
#     875,
#     1112,
#     5841,
#     6139,
#     6235,
#     6330,
#     12816,
#     15904,
#     15933,
#     16110,
#     16334,
#     16605,
#     16814,
#     17001,
#     17151,
#     17352,
#     18035,
#     18815,
#     20516,
#     20792,
#     20919,
#     21129,
#     21158,
#     21224,
#     21458,
#     21575,
#     21811,
#     22167,
#     34336,
#     34633,
#     36277,
#     36378,
#     36510,
#     39866,
#     39952,
#     50043,
#     50934,
#     51251,
#     51313,
#     51901,
#     52845,
#     53187,
#     53248,
#     54321,
#     54408,
#     54474,
#     54519,
#     57013,
#     57547,
#     57596,
#     57624,
#     59056,
#     59183,
#     59622,
#     59654,
#     59752,
#     60155,
#     60703,
#     61099,
#     61236,
#     61520,
#     61827,
#     62598,
#     62872,
#     62954,
#     66355,
#     66433,
#     66585,
#     67623,
#     68864,
#     69391,
#     69530,
#     69968,
#     70491,
#     75171,
#     78089,
#     79973,
#     80579,
#     81743,
#     81833,
#     83857,
#     89970]],
#   ['pdf2text_op\\ysdl96amj.txt', [65356]],
#   ['pdf2text_op\\yyhp13jcp.txt', [21292]],
#   ['pdf2text_op\\yzpl13ijpe.txt', [25401]],
#   ['pdf2text_op\\zzyz10jbe.txt', [17851]]],
#  'customer focus': [['pdf2text_op\\a098ijqs.txt',
#    [5744,
#     6176,
#     20686,
#     21997,
#     26542,
#     27032,
#     27498,
#     28263,
#     28360,
#     35677,
#     36341,
#     48843,
#     49884,
#     50803,
#     53458,
#     54757,
#     55385,
#     55711,
#     57339,
#     58595,
#     59149,
#     59497,
#     60059,
#     60735,
#     62657,
#     62820,
#     63752,
#     66876,
#     67416,
#     68602,
#     71681,
#     71987,
#     80417,
#     99753,
#     100056]],
#   ['pdf2text_op\\a09jhr.txt', [15117, 26287, 41426]],
#   ['pdf2text_op\\ad00jom.txt', [32663]],
#   ['pdf2text_op\\c12dissertation.txt', [38675]],
#   ['pdf2text_op\\cakm09josr.txt', [62955]],
#   ['pdf2text_op\\cb07imm.txt', [27097, 31836, 46661]],
#   ['pdf2text_op\\cvd00ds.txt', [2703, 2794, 15130]],
#   ['pdf2text_op\\cww15ijpdlm.txt', [32291]],
#   ['pdf2text_op\\dsf99pom.txt', [75706]],
#   ['pdf2text_op\\g00dissertation.txt', [19891, 32579, 174698, 177622]],
#   ['pdf2text_op\\jxn11ijpr.txt', [3240, 41088]],
#   ['pdf2text_op\\k03jom.txt',
#    [23379, 24644, 24748, 25097, 26486, 26602, 26842, 28015, 86072, 86223]],
#   ['pdf2text_op\\k99dissertation.txt', [144935, 312330, 315299]],
#   ['pdf2text_op\\lj03emj.txt', [6557, 6747, 41490]],
#   ['pdf2text_op\\lpaf13jcp.txt', [34086]],
#   ['pdf2text_op\\m94dissertation.txt', [121514]],
#   ['pdf2text_op\\ps03ijqrm.txt', [9804, 22821, 24649, 28320, 37857]],
#   ['pdf2text_op\\rsss01jom.txt', [18135]],
#   ['pdf2text_op\\s98dissertation.txt', [378178]],
#   ['pdf2text_op\\sbj04apair.txt', [4591, 33824]],
#   ['pdf2text_op\\slg07isr.txt', [36916, 50412]],
#   ['pdf2text_op\\slr13jpim.txt', [16015]],
#   ['pdf2text_op\\st99jom.txt',
#    [1576,
#     3042,
#     15510,
#     15937,
#     17152,
#     21391,
#     26966,
#     33459,
#     41770,
#     44563,
#     49761]]],
#  'market share': [['pdf2text_op\\a11eee.txt', [27435]],
#   ['pdf2text_op\\abc01o.txt', [27858]],
#   ['pdf2text_op\\abw11jpa.txt', [15128]],
#   ['pdf2text_op\\ad00jom.txt', [1308, 10267, 10416, 94509]],
#   ['pdf2text_op\\aly10jom.txt', [11868]],
#   ['pdf2text_op\\ay14ijbs.txt', [20311, 21233]],
#   ['pdf2text_op\\azw06meq.txt', [4630, 23362, 60704]],
#   ['pdf2text_op\\azw06meqij.txt', [1824, 20046, 56453]],
#   ['pdf2text_op\\b92ilrr.txt',
#    [12774, 14535, 14714, 15088, 29229, 32791, 36432, 59767, 60088]],
#   ['pdf2text_op\\b99dissertation.txt',
#    [57558, 106302, 115073, 216884, 222276]],
#   ['pdf2text_op\\bb95jibs.txt', [12579]],
#   ['pdf2text_op\\bcwlw03ijhrm.txt', [52476]],
#   ['pdf2text_op\\bnk00jbr.txt', [44403, 48709, 52624]],
#   ['pdf2text_op\\bs05jams.txt',
#    [235,
#     997,
#     4939,
#     18519,
#     18777,
#     19406,
#     19597,
#     22400,
#     27391,
#     27653,
#     28026,
#     28185,
#     36384,
#     36862,
#     37902,
#     37944,
#     38003,
#     41847,
#     41891,
#     41994,
#     45296,
#     47177,
#     47339,
#     47645,
#     47925,
#     48034,
#     48414,
#     48991,
#     49633,
#     54212,
#     54534,
#     54946,
#     56777,
#     61523,
#     61693,
#     61717]],
#   ['pdf2text_op\\bsgrd06smj.txt', [18864, 41432, 63523]],
#   ['pdf2text_op\\bw04jbr.txt', [24668]],
#   ['pdf2text_op\\c03dissertation.txt', [191276]],
#   ['pdf2text_op\\c12dissertation.txt', [51521]],
#   ['pdf2text_op\\cb07imm.txt', [23981]],
#   ['pdf2text_op\\cc10sij.txt', [17764, 17879, 27150]],
#   ['pdf2text_op\\cc12jbe.txt', [22735, 41602]],
#   ['pdf2text_op\\ce98jom.txt', [1656, 15276, 15425, 15660, 57057, 64225]],
#   ['pdf2text_op\\cfk97wpvanderbiltuniversity.txt', [25369]],
#   ['pdf2text_op\\cgl09jom.txt', [4869]],
#   ['pdf2text_op\\ch15omr.txt', [10888, 43416, 66073, 68800, 70685]],
#   ['pdf2text_op\\chcw12imm.txt', [33278, 34740, 62316]],
#   ['pdf2text_op\\chl09ijhrm.txt', [30205]],
#   ['pdf2text_op\\cl10pp.txt',
#    [7180, 30287, 45443, 74845, 84213, 86417, 108738]],
#   ['pdf2text_op\\ct05crr.txt',
#    [817,
#     5935,
#     23802,
#     24529,
#     25027,
#     25139,
#     25208,
#     29607,
#     29694,
#     35173,
#     36251,
#     37631,
#     37713,
#     37773,
#     37924,
#     38552,
#     38630,
#     38643,
#     38677,
#     44558,
#     45001,
#     45210,
#     45286,
#     45349,
#     63583]],
#   ['pdf2text_op\\ctsm08jem.txt', [84559]],
#   ['pdf2text_op\\cvd00ds.txt',
#    [1221,
#     23164,
#     23264,
#     28702,
#     28827,
#     28934,
#     29356,
#     29601,
#     29832,
#     33400,
#     33701,
#     33925,
#     34031,
#     34265,
#     34327,
#     37750,
#     37768,
#     41163]],
#   ['pdf2text_op\\cww15ijpdlm.txt', [5842, 6039, 24090]],
#   ['pdf2text_op\\cys14jcp.txt', [20988, 27189, 58885]],
#   ['pdf2text_op\\cz11jom.txt', [30270, 92107]],
#   ['pdf2text_op\\d00jom.txt',
#    [36674, 39288, 39467, 41103, 45037, 45439, 45515, 45861, 47208, 65415]],
#   ['pdf2text_op\\d03jom.txt', [20815, 31455]],
#   ['pdf2text_op\\dc05jms.txt', [40574, 46881]],
#   ['pdf2text_op\\dga15ijpe.txt', [19978]],
#   ['pdf2text_op\\dj01amj.txt', [22233, 53832]],
#   ['pdf2text_op\\djv04jom.txt',
#    [772,
#     1591,
#     5428,
#     6012,
#     19827,
#     26345,
#     28896,
#     29298,
#     29733,
#     30578,
#     32113,
#     33656,
#     33683,
#     33717,
#     34200,
#     38758,
#     38785,
#     39514,
#     39987,
#     40010,
#     40554,
#     41194,
#     41949,
#     41983,
#     42845,
#     44183,
#     44743,
#     45118,
#     48888,
#     49044,
#     50045,
#     50838,
#     50903,
#     51003,
#     52743]],
#   ['pdf2text_op\\ej92ms.txt', [57716]],
#   ['pdf2text_op\\fbp00ijhrm.txt', [28279]],
#   ['pdf2text_op\\fcwz15jcp.txt', [57597, 59078]],
#   ['pdf2text_op\\ffp14ijopm.txt', [4145]],
#   ['pdf2text_op\\fhz10jom.txt', [16629, 69810]],
#   ['pdf2text_op\\fw02jom.txt', [44951]],
#   ['pdf2text_op\\g00dissertation.txt', [80545, 80624, 135669, 154611]],
#   ['pdf2text_op\\g98smj.txt', [25707, 43031]],
#   ['pdf2text_op\\gw12jsm.txt', [28669, 55338, 55384, 55423]],
#   ['pdf2text_op\\gwm11pp.txt', [48048]],
#   ['pdf2text_op\\gzw06meq.txt', [4534, 23212, 60455]],
#   ['pdf2text_op\\h00jmis.txt', [11695]],
#   ['pdf2text_op\\h82jie.txt', [5166]],
#   ['pdf2text_op\\h85jb.txt',
#    [4049,
#     4702,
#     6043,
#     8212,
#     13698,
#     15437,
#     15752,
#     17358,
#     19251,
#     19356,
#     20086,
#     21064,
#     22669,
#     22862,
#     24131,
#     26340]],
#   ['pdf2text_op\\hcnw09jbe.txt', [15257, 21346, 45136]],
#   ['pdf2text_op\\hd04smj.txt',
#    [9924, 9970, 11622, 11785, 11882, 32861, 75115]],
#   ['pdf2text_op\\hjr12ppc.txt', [10247]],
#   ['pdf2text_op\\hlsc14ijpe.txt', [21769, 39439]],
#   ['pdf2text_op\\hpcl09ijopm.txt', [38155, 40224]],
#   ['pdf2text_op\\hs04jams.txt', [60603]],
#   ['pdf2text_op\\hw01ijaar.txt', [29732]],
#   ['pdf2text_op\\hw85jar.txt', [5364, 10338]],
#   ['pdf2text_op\\hw89smj.txt', [7669, 28154]],
#   ['pdf2text_op\\hy14mrr.txt', [34319, 69476]],
#   ['pdf2text_op\\j07dissertation.txt',
#    [16312,
#     16484,
#     16660,
#     63103,
#     64634,
#     101554,
#     101882,
#     102107,
#     102175,
#     118523,
#     123317,
#     123483,
#     123928,
#     124052,
#     124251,
#     125263,
#     127706,
#     128215,
#     128398,
#     129887,
#     132600,
#     133851,
#     134731,
#     134840,
#     136762,
#     139083,
#     139366,
#     139544,
#     140336,
#     142199,
#     142552,
#     143290,
#     155106,
#     155175,
#     159455,
#     159580,
#     159671,
#     163248,
#     164525,
#     169828,
#     170129,
#     170426,
#     170936,
#     173673,
#     174033,
#     312818,
#     312923,
#     313016]],
#   ['pdf2text_op\\jd98jms.txt', [36149, 38382, 52116]],
#   ['pdf2text_op\\jd98jom.txt', [36109, 53661]],
#   ['pdf2text_op\\jd98joms.txt', [36149, 38382, 52116]],
#   ['pdf2text_op\\jdrv13ijpr.txt', [24326, 25082]],
#   ['pdf2text_op\\JOM-18-0621.txt', [39617]],
#   ['pdf2text_op\\jpd03jbr.txt', [36206]],
#   ['pdf2text_op\\k03jom.txt',
#    [13524,
#     13542,
#     17285,
#     19510,
#     22876,
#     27877,
#     27941,
#     27955,
#     47143,
#     76118,
#     98785,
#     98827,
#     102268]],
#   ['pdf2text_op\\k07jpim.txt', [20802]],
#   ['pdf2text_op\\kcmw13jepm.txt', [11952, 22660, 24000]],
#   ['pdf2text_op\\km05smj.txt', [25630]],
#   ['pdf2text_op\\kr12ijpr.txt', [45274]],
#   ['pdf2text_op\\l00thesis.txt', [126560]],
#   ['pdf2text_op\\l02jbr.txt', [58229]],
#   ['pdf2text_op\\lb98gjhr.txt', [13095, 14482, 43121]],
#   ['pdf2text_op\\lcy12ijebm.txt', [3331, 55031]],
#   ['pdf2text_op\\lh05item.txt', [3060, 12755, 13816, 14258]],
#   ['pdf2text_op\\lj03emj.txt', [45366]],
#   ['pdf2text_op\\lm96os.txt', [28242, 45538]],
#   ['pdf2text_op\\lmssh02ms.txt', [38376, 44056, 45385, 57028, 62567, 72307]],
#   ['pdf2text_op\\lpaf13jcp.txt', [47610]],
#   ['pdf2text_op\\ls00nvsq.txt', [42476]],
#   ['pdf2text_op\\ltg13jcp.txt', [7259]],
#   ['pdf2text_op\\lw98hrdq.txt', [20750, 21477, 22019, 25864]],
#   ['pdf2text_op\\lwl14bijpe.txt', [41690, 46513]],
#   ['pdf2text_op\\lww13ijpe.txt', [59318]],
#   ['pdf2text_op\\m08amp.txt',
#    [4162,
#     6156,
#     6440,
#     6471,
#     6513,
#     7139,
#     7571,
#     7687,
#     7804,
#     8677,
#     8794,
#     9110,
#     9142,
#     9290,
#     9447,
#     9498,
#     9636,
#     9802,
#     9890,
#     9935,
#     10140,
#     10453,
#     10945,
#     12242,
#     12549,
#     14130]],
#   ['pdf2text_op\\m97amp.txt', [16111]],
#   ['pdf2text_op\\mb05ejm.txt', [38652, 38817, 70678]],
#   ['pdf2text_op\\mdg00ijpr.txt',
#    [1476,
#     13298,
#     13346,
#     16063,
#     16125,
#     16244,
#     16366,
#     16840,
#     16934,
#     17025,
#     17163,
#     17305,
#     17353,
#     17810,
#     18171,
#     18383,
#     18638,
#     18856,
#     18887,
#     18974,
#     19228,
#     22689,
#     27230,
#     31545,
#     31643,
#     31710,
#     32038,
#     32905,
#     33162,
#     33276,
#     33637,
#     33880,
#     33932,
#     34041,
#     34131,
#     35333,
#     35705,
#     37908,
#     38044,
#     38877,
#     47177,
#     50542]],
#   ['pdf2text_op\\mo05jbr.txt',
#    [1022,
#     24976,
#     25082,
#     25889,
#     27324,
#     33762,
#     34215,
#     34406,
#     34927,
#     35310,
#     37789]],
#   ['pdf2text_op\\ms09jom.txt', [34825, 68732, 71311]],
#   ['pdf2text_op\\ms10jbe.txt', [16108, 30539, 46809, 106101]],
#   ['pdf2text_op\\ms96amj.txt',
#    [39801, 49621, 51203, 55426, 55909, 56620, 57060, 60103, 62899, 65644]],
#   ['pdf2text_op\\mt09jms.txt', [15889]],
#   ['pdf2text_op\\myb12hrmj.txt', [50959]],
#   ['pdf2text_op\\n08jfe.txt', [130154, 132490]],
#   ['pdf2text_op\\odmm12jbl.txt', [38435]],
#   ['pdf2text_op\\p04crr.txt', [33577, 40589, 41806]],
#   ['pdf2text_op\\pb00amj.txt', [20871]],
#   ['pdf2text_op\\pd97smj.txt', [12198, 88412]],
#   ['pdf2text_op\\pl01smj.txt', [78211]],
#   ['pdf2text_op\\pl06jap.txt', [16613]],
#   ['pdf2text_op\\rbcc15jscm.txt', [33288]],
#   ['pdf2text_op\\rbm09jbe.txt', [30545, 33180]],
#   ['pdf2text_op\\rf97amj.txt', [38659, 38685]],
#   ['pdf2text_op\\rh06os.txt',
#    [51053,
#     51243,
#     51309,
#     51845,
#     52175,
#     52615,
#     60148,
#     60194,
#     62603,
#     62857,
#     62908,
#     62963,
#     63056,
#     77499,
#     78412,
#     78711,
#     79609,
#     79842,
#     81715,
#     95559,
#     95774,
#     96202]],
#   ['pdf2text_op\\rsj86pp.txt', [16285, 21792]],
#   ['pdf2text_op\\s00jom.txt', [41596]],
#   ['pdf2text_op\\s08dissertation.txt', [411695]],
#   ['pdf2text_op\\s97amj.txt', [15219, 16497, 39222, 44578]],
#   ['pdf2text_op\\sab07md.txt', [9314, 21711]],
#   ['pdf2text_op\\sc00ijsim.txt', [5403, 6079]],
#   ['pdf2text_op\\sh11jop.txt', [33394]],
#   ['pdf2text_op\\skh06ejm.txt', [7644, 7767, 20825, 53552]],
#   ['pdf2text_op\\slg07isr.txt', [22826, 70569]],
#   ['pdf2text_op\\smg05dsj.txt', [52206, 77847]],
#   ['pdf2text_op\\sn01jpim.txt', [39464, 74855]],
#   ['pdf2text_op\\snk05dsj.txt', [30793, 30991, 45938, 46009, 87332]],
#   ['pdf2text_op\\snw07jom.txt', [39462, 39496, 47525, 65233]],
#   ['pdf2text_op\\ss07etp.txt', [17188, 18951, 33992]],
#   ['pdf2text_op\\ss15jbl.txt', [82597]],
#   ['pdf2text_op\\ss93ms.txt',
#    [9177,
#     28179,
#     33799,
#     35796,
#     36216,
#     36286,
#     36402,
#     36595,
#     36653,
#     36767,
#     36893,
#     36938,
#     36990,
#     37067,
#     38450,
#     39313,
#     39435,
#     41660,
#     42461,
#     42517,
#     43587,
#     44030,
#     44107,
#     44192,
#     44525,
#     44681,
#     44971,
#     45133,
#     45247,
#     45408,
#     45512,
#     46222,
#     46487,
#     48993,
#     60689,
#     61455,
#     61747,
#     65554,
#     67162,
#     67218,
#     69219,
#     70878,
#     71035,
#     73552,
#     74139,
#     75484,
#     77212,
#     86478,
#     88728,
#     95936]],
#   ['pdf2text_op\\st99jom.txt', [3523]],
#   ['pdf2text_op\\sz13jpim.txt', [68433]],
#   ['pdf2text_op\\tc08gom.txt', [38035]],
#   ['pdf2text_op\\tps12ds.txt', [41052, 41085, 41151, 41274]],
#   ['pdf2text_op\\vr87jom.txt', [8174]],
#   ['pdf2text_op\\w05eqm.txt', [18235]],
#   ['pdf2text_op\\wb07jams.txt', [64487]],
#   ['pdf2text_op\\wb93smj.txt', [19104, 28105]],
#   ['pdf2text_op\\wccs14s.txt', [23482]],
#   ['pdf2text_op\\wdw06jsm.txt', [32639]],
#   ['pdf2text_op\\wqk10jbe.txt', [11674]],
#   ['pdf2text_op\\wqk11jbe.txt', [11674]],
#   ['pdf2text_op\\wwcg14ijpe.txt', [37041]],
#   ['pdf2text_op\\y07tqm.txt', [42615, 45466]],
#   ['pdf2text_op\\y07tqmbe.txt', [42615, 45466]],
#   ['pdf2text_op\\yjse13ijpe.txt', [37019, 40211, 69991]],
#   ['pdf2text_op\\ys03jbr.txt', [58991]],
#   ['pdf2text_op\\yzpl13ijpe.txt', [48407]],
#   ['pdf2text_op\\zh13ijpdlm.txt', [21201, 42295]],
#   ['pdf2text_op\\zjvp12aijpe.txt', [20620, 38135, 57620]],
#   ['pdf2text_op\\zmzttj11jcp.txt',
#    [10755, 15119, 18454, 21007, 28264, 28952, 43112, 44636, 46042, 50731]],
#   ['pdf2text_op\\zsl07jcp.txt', [5185, 38507, 50159]],
#   ['pdf2text_op\\zzyz10jbe.txt', [22805]]],
#  'corporate reputation': [['pdf2text_op\\abs04crr.txt',
#    [0, 2874, 4775, 9485, 10257, 34020, 34669, 34991, 35732]],
#   ['pdf2text_op\\ar07lrp.txt', [3581]],
#   ['pdf2text_op\\bbt09jbp.txt', [36124, 36498]],
#   ['pdf2text_op\\bc15apjm.txt', [14254, 74964]],
#   ['pdf2text_op\\bds94jmi.txt', [51154]],
#   ['pdf2text_op\\bjl06crr.txt',
#    [0,
#     65,
#     944,
#     1557,
#     1774,
#     2026,
#     2435,
#     2534,
#     2626,
#     3066,
#     3249,
#     4482,
#     6208,
#     6361,
#     6723,
#     7355,
#     7390,
#     10835,
#     11721,
#     13427,
#     13463,
#     14313,
#     15161,
#     16175,
#     16210,
#     16271,
#     18159,
#     20387,
#     20422,
#     20882,
#     22750,
#     23181,
#     23313,
#     23927,
#     25097,
#     25488,
#     26285,
#     26410,
#     27672,
#     27707,
#     29140,
#     30036,
#     30355,
#     31803,
#     32593,
#     32904,
#     36288,
#     36323,
#     36682,
#     41139,
#     42435,
#     43011,
#     44787,
#     44970,
#     45200,
#     47164,
#     49410,
#     49655,
#     49945,
#     49980,
#     50081,
#     52198]],
#   ['pdf2text_op\\bm05jbe.txt',
#    [92,
#     248,
#     5080,
#     5798,
#     6246,
#     6433,
#     7605,
#     9012,
#     9845,
#     10505,
#     10582,
#     10721,
#     17983,
#     22124,
#     22161,
#     26475,
#     26499,
#     27179,
#     27213,
#     27460,
#     35020,
#     39494,
#     42091,
#     51450,
#     51725,
#     53608,
#     58473,
#     59604,
#     60864,
#     60923,
#     61088,
#     62944,
#     63023]],
#   ['pdf2text_op\\bm10ir.txt',
#    [2241,
#     19861,
#     20433,
#     20683,
#     20780,
#     20862,
#     23896,
#     24020,
#     24067,
#     24705,
#     24833,
#     29645,
#     29965,
#     31837,
#     33097,
#     35199,
#     35277,
#     35339,
#     37505,
#     38367,
#     42957,
#     46655,
#     46988,
#     47096,
#     47179,
#     51116,
#     52641,
#     55111,
#     59872,
#     60752]],
#   ['pdf2text_op\\bmp09bjm.txt',
#    [92,
#     388,
#     1166,
#     5046,
#     5742,
#     5958,
#     6109,
#     6600,
#     6831,
#     7039,
#     7344,
#     8432,
#     8585,
#     11260,
#     11375,
#     11603,
#     12580,
#     18282,
#     25604,
#     25818,
#     25877,
#     35109,
#     35212,
#     36245,
#     43274,
#     43906,
#     44802,
#     48246,
#     49456,
#     49506,
#     50007,
#     50066,
#     52367,
#     54096,
#     54191]],
#   ['pdf2text_op\\bo07aaa.txt', [11442]],
#   ['pdf2text_op\\bp04beer.txt', [34309]],
#   ['pdf2text_op\\bp04emj.txt',
#    [927,
#     6008,
#     6784,
#     6926,
#     8361,
#     8456,
#     11859,
#     14747,
#     18666,
#     19780,
#     19813,
#     24619,
#     42236]],
#   ['pdf2text_op\\bp06jms.txt',
#    [55,
#     1182,
#     2426,
#     2591,
#     3208,
#     4038,
#     5615,
#     5761,
#     6573,
#     6803,
#     6880,
#     7019,
#     8302,
#     10092,
#     10546,
#     11815,
#     15410,
#     15443,
#     17674,
#     19883,
#     22404,
#     22649,
#     24011,
#     25335,
#     28344,
#     33668,
#     34284,
#     38958,
#     39590,
#     45691,
#     45833,
#     46519,
#     47435,
#     48731,
#     51318,
#     51641,
#     54866,
#     54889,
#     56302,
#     56457,
#     56519,
#     58527,
#     59192,
#     59406,
#     61296,
#     61329]],
#   ['pdf2text_op\\bp94amj.txt', [6274, 33747, 33849]],
#   ['pdf2text_op\\brm11jbe.txt',
#    [7091, 7365, 24487, 30752, 31545, 33001, 37568, 59804]],
#   ['pdf2text_op\\brp10jbe.txt',
#    [440,
#     599,
#     951,
#     985,
#     1112,
#     3142,
#     3282,
#     4238,
#     5578,
#     5791,
#     5978,
#     6457,
#     8291,
#     9164,
#     9459,
#     10466,
#     16823,
#     21866,
#     22119,
#     22249,
#     30527,
#     30650,
#     30962,
#     31606,
#     32470,
#     34538,
#     35846,
#     36031,
#     39827,
#     40696,
#     44120,
#     44269,
#     45341,
#     48429,
#     48547,
#     52896,
#     52943,
#     58036]],
#   ['pdf2text_op\\bsgrd06smj.txt', [34927, 61692, 61714, 64316, 64420, 67305]],
#   ['pdf2text_op\\bw11jbr.txt',
#    [151,
#     364,
#     526,
#     1178,
#     1321,
#     1644,
#     2465,
#     3257,
#     3706,
#     4155,
#     4186,
#     4816,
#     6706,
#     7603,
#     13959,
#     18866,
#     19531,
#     22194,
#     22377,
#     25747,
#     30245,
#     32661,
#     34533,
#     34668,
#     35688,
#     35834,
#     36082]],
#   ['pdf2text_op\\bwb11jbr.txt',
#    [158,
#     748,
#     1644,
#     1769,
#     2934,
#     3947,
#     5393,
#     5603,
#     6352,
#     25954,
#     35803,
#     35954,
#     38498,
#     39003,
#     39301,
#     39798,
#     40566,
#     41599,
#     41750,
#     42529,
#     44975,
#     45220,
#     45722]],
#   ['pdf2text_op\\c06jms.txt',
#    [145,
#     527,
#     1672,
#     1696,
#     2875,
#     5458,
#     5862,
#     7860,
#     11683,
#     11924,
#     12079,
#     15843,
#     17225,
#     22981,
#     23593,
#     29514,
#     35639,
#     38750,
#     38855,
#     41283,
#     41385,
#     45843,
#     46998,
#     47564,
#     47614,
#     52892,
#     53629,
#     56371,
#     58724,
#     58973,
#     63470,
#     64256,
#     65986,
#     66048,
#     70584,
#     74097,
#     76757,
#     76832,
#     77061,
#     78435,
#     84347,
#     84905,
#     88688,
#     92753,
#     93369,
#     95183,
#     97613]],
#   ['pdf2text_op\\cb07imm.txt',
#    [4094,
#     8258,
#     15242,
#     25793,
#     29715,
#     34804,
#     44961,
#     53589,
#     53964,
#     56526,
#     56602,
#     57210,
#     62097]],
#   ['pdf2text_op\\cck06jbm.txt',
#    [0,
#     1399,
#     1488,
#     1525,
#     1629,
#     1901,
#     2002,
#     2038,
#     3895,
#     4409,
#     5448,
#     6599,
#     7250,
#     7827,
#     8221,
#     13669,
#     13857,
#     14535,
#     15016,
#     15854,
#     16071,
#     16742,
#     18464,
#     18907,
#     19887,
#     19996,
#     21212,
#     21369,
#     21518,
#     22816,
#     23846,
#     24133,
#     25028,
#     25612,
#     26469,
#     26696,
#     28173,
#     28879,
#     28972,
#     29238,
#     29508,
#     30376,
#     30451,
#     31133,
#     31257,
#     31960,
#     32510,
#     32589,
#     33454,
#     33495,
#     33861,
#     35848,
#     37313]],
#   ['pdf2text_op\\cct10lodj.txt',
#    [958,
#     4039,
#     5881,
#     6205,
#     6706,
#     6867,
#     7284,
#     8710,
#     13096,
#     24613,
#     27826,
#     27995,
#     32010,
#     33444,
#     38474,
#     41681,
#     47038,
#     51187,
#     52030,
#     53978]],
#   ['pdf2text_op\\ccv10prr.txt', [558, 981, 1624, 24215, 28572, 29657, 30924]],
#   ['pdf2text_op\\cd10imm.txt',
#    [169, 603, 3846, 5913, 12256, 12468, 35880, 40246, 40469, 40527]],
#   ['pdf2text_op\\ce10jbr.txt',
#    [127,
#     535,
#     621,
#     993,
#     1194,
#     3648,
#     6327,
#     6514,
#     6577,
#     6960,
#     7164,
#     7403,
#     7877,
#     9419,
#     9888,
#     10372,
#     10655,
#     11172,
#     15488,
#     15610,
#     15703,
#     15794,
#     15887,
#     19168,
#     19360,
#     23768,
#     23869,
#     23960,
#     24077,
#     24910,
#     27802,
#     28466,
#     28596,
#     29374,
#     29433,
#     29552,
#     29595,
#     30099,
#     30154,
#     31583,
#     33840,
#     35514,
#     35746,
#     35952,
#     36220,
#     36931,
#     37267,
#     40028,
#     40111,
#     42904]],
#   ['pdf2text_op\\ces06ee.txt', [37469]],
#   ['pdf2text_op\\cg00job.txt', [10848, 66044, 69942, 70902]],
#   ['pdf2text_op\\chcw12imm.txt', [19756]],
#   ['pdf2text_op\\CHINA wq11amj.txt', [86486]],
#   ['pdf2text_op\\ckc10ajm.txt', [13662]],
#   ['pdf2text_op\\cls06jbe.txt',
#    [1251,
#     1424,
#     2038,
#     3506,
#     3602,
#     3856,
#     4413,
#     4687,
#     6006,
#     6053,
#     6353,
#     7212,
#     8640,
#     8887,
#     9008,
#     10102,
#     10335,
#     10953,
#     11408,
#     14572,
#     15511,
#     16014,
#     17494,
#     20216,
#     22956,
#     24756,
#     25390,
#     26020,
#     26159,
#     26582,
#     26952,
#     27541,
#     28247,
#     28375,
#     30826,
#     30906,
#     34099,
#     34370]],
#   ['pdf2text_op\\ct04smj.txt', [40506, 88523]],
#   ['pdf2text_op\\ct05crr.txt',
#    [0, 2555, 15284, 15505, 16624, 19441, 50999, 54615, 59782, 61102]],
#   ['pdf2text_op\\cw09smj.txt', [46013]],
#   ['pdf2text_op\\d00jom.txt',
#    [59019, 62106, 64352, 69586, 71181, 71303, 73718, 73775, 74935, 75098]],
#   ['pdf2text_op\\d03jom.txt', [32324]],
#   ['pdf2text_op\\dc05jms.txt', [22404, 87795, 87879, 88134, 98357]],
#   ['pdf2text_op\\dhk11bs.txt', [24136]],
#   ['pdf2text_op\\dls06jbe.txt',
#    [171,
#     344,
#     950,
#     2403,
#     2496,
#     2746,
#     3298,
#     3568,
#     4746,
#     5092,
#     5937,
#     7340,
#     7582,
#     7700,
#     8657,
#     8886,
#     9493,
#     9938,
#     12176,
#     13220,
#     14207,
#     15679,
#     18343,
#     24764,
#     25256,
#     25942,
#     26068,
#     26488,
#     27090,
#     27252,
#     27666,
#     28028,
#     30872,
#     30950,
#     33985,
#     34252]],
#   ['pdf2text_op\\dss07jbv.txt', [68927]],
#   ['pdf2text_op\\eck10crr.txt',
#    [0,
#     117,
#     1306,
#     2629,
#     4419,
#     7115,
#     7269,
#     7433,
#     10708,
#     11525,
#     15553,
#     19525,
#     21474,
#     22179,
#     23104,
#     27399,
#     31109,
#     31633,
#     34537,
#     38964,
#     41518,
#     45283,
#     45481,
#     48614,
#     50268,
#     51401,
#     51814,
#     52840,
#     54037,
#     57577,
#     58163,
#     60495,
#     60525,
#     63910,
#     65353,
#     67879]],
#   ['pdf2text_op\\ecl99ccaij.txt',
#    [1,
#     261,
#     494,
#     661,
#     862,
#     3346,
#     3596,
#     3646,
#     4731,
#     5752,
#     6220,
#     8050,
#     8904,
#     9654,
#     13384,
#     13487,
#     13782,
#     15417,
#     19605,
#     20268,
#     20389,
#     20558,
#     20743,
#     21088,
#     22058,
#     22320,
#     22837,
#     26048,
#     26127,
#     26223]],
#   ['pdf2text_op\\elw06jbr.txt', [48365]],
#   ['pdf2text_op\\f06bsr.txt', [8665, 20092, 43705, 47624, 48092, 48432]],
#   ['pdf2text_op\\fo05jom.txt',
#    [902, 1016, 10195, 20095, 41333, 41872, 49136, 49592, 51854, 57576, 58816]],
#   ['pdf2text_op\\fs90amj.txt',
#    [4020, 30191, 34922, 45864, 49144, 49842, 51365, 57461]],
#   ['pdf2text_op\\fsa96icfk.txt', [52940]],
#   ['pdf2text_op\\gb07crr.txt',
#    [0,
#     103,
#     1477,
#     1689,
#     3225,
#     3406,
#     5989,
#     7456,
#     9140,
#     11701,
#     11773,
#     11939,
#     13319,
#     14900,
#     15518,
#     17371,
#     19988,
#     20060,
#     24088,
#     27897,
#     27969,
#     30841,
#     31939,
#     35284,
#     35356,
# ...
#   ['pdf2text_op\\sh10imm.txt', [5461, 43761]],
#   ['pdf2text_op\\sh11jop.txt', [44324, 46003]],
#   ['pdf2text_op\\skh06ejm.txt', [2282, 21365, 48963]],
#   ['pdf2text_op\\sz13jpim.txt',
#    [212,
#     907,
#     968,
#     1617,
#     4445,
#     5006,
#     11466,
#     11849,
#     12583,
#     15850,
#     20440,
#     25419,
#     26170,
#     27130,
#     27672,
#     28127,
#     28516,
#     28730,
#     29193,
#     29460,
#     29648,
#     30042,
#     31048,
#     32702,
#     32783,
#     33661,
#     33716,
#     33950,
#     35570,
#     35667,
#     37097,
#     40603,
#     44122,
#     44278,
#     48593,
#     49555,
#     50028,
#     50158,
#     50325,
#     50436,
#     51023,
#     51336,
#     51697,
#     51781,
#     51845,
#     51981,
#     52587,
#     52695,
#     53218,
#     53862,
#     56469,
#     59156,
#     60855,
#     61852,
#     61945,
#     62608,
#     64117,
#     75713,
#     81370]],
#   ['pdf2text_op\\w10misq.txt', [42471]],
#   ['pdf2text_op\\wb07jams.txt', [70581]],
#   ['pdf2text_op\\wbs09ajbr.txt', [31663]],
#   ['pdf2text_op\\wdw06jsm.txt', [2198, 13130]],
#   ['pdf2text_op\\wew07jbr.txt', [37558]],
#   ['pdf2text_op\\wlsl14bse.txt', [18052]],
#   ['pdf2text_op\\wmjb09bjm.txt',
#    [1244,
#     3972,
#     28297,
#     28809,
#     29296,
#     37855,
#     38196,
#     38281,
#     38759,
#     39386,
#     41221,
#     42695,
#     42939,
#     43208,
#     49132,
#     52663,
#     58845]],
#   ['pdf2text_op\\y07tqm.txt', [5809, 6115]],
#   ['pdf2text_op\\y07tqmbe.txt', [5809, 6115]],
#   ['pdf2text_op\\yjse13ijpe.txt', [21742, 70410]],
#   ['pdf2text_op\\yyhp13jcp.txt', [21318]],
#   ['pdf2text_op\\yzpl13ijpe.txt', [23886, 26140, 50160]],
#   ['pdf2text_op\\zlw14jbe.txt', [31011]],
#   ['pdf2text_op\\zsl14apjm.txt', [20424]],
#   ['pdf2text_op\\zzyz10jbe.txt', [47903]]],
#  'customer integration': [['pdf2text_op\\amm15ijpe.txt',
#    [1913, 5738, 11776, 41660, 91097]],
#   ['pdf2text_op\\bw11jbr.txt', [24502]],
#   ['pdf2text_op\\c03dissertation.txt', [34763, 34846, 39191]],
#   ['pdf2text_op\\c12dissertation.txt',
#    [40509, 226552, 232147, 236587, 245616]],
#   ['pdf2text_op\\cclc11treltr.txt', [68420]],
#   ['pdf2text_op\\djv04jom.txt', [8333]],
#   ['pdf2text_op\\dkw07jom.txt',
#    [787,
#     1236,
#     1439,
#     1921,
#     19705,
#     19898,
#     19986,
#     20073,
#     20161,
#     24103,
#     34392,
#     46301,
#     46557,
#     48352,
#     49134,
#     49589,
#     53195,
#     54091,
#     54217,
#     54310,
#     54447,
#     54513,
#     54683,
#     54902,
#     59791,
#     60034,
#     62458,
#     62789,
#     62953]],
#   ['pdf2text_op\\dr13ijopm.txt', [296, 670]],
#   ['pdf2text_op\\ffp14ijopm.txt', [1643, 52198]],
#   ['pdf2text_op\\fhz10jom.txt',
#    [2634,
#     10913,
#     16118,
#     18247,
#     18464,
#     21036,
#     21251,
#     21511,
#     27036,
#     28023,
#     39439,
#     40033,
#     40106,
#     41255,
#     41324,
#     41937,
#     42578,
#     42813,
#     43726,
#     43799,
#     44340,
#     44668,
#     48153,
#     49080,
#     49663,
#     49887,
#     51387,
#     51508,
#     51765,
#     52234,
#     52526,
#     54667,
#     59073,
#     63294,
#     63393,
#     63436,
#     63631,
#     63768,
#     64594,
#     64888,
#     65469,
#     65905]],
#   ['pdf2text_op\\fw02jom.txt', [44235]],
#   ['pdf2text_op\\gw12jsm.txt', [44914]],
#   ['pdf2text_op\\hlsc14ijpe.txt',
#    [208,
#     953,
#     1237,
#     1387,
#     1675,
#     1820,
#     2022,
#     4640,
#     4761,
#     4883,
#     5609,
#     6481,
#     6635,
#     6965,
#     7113,
#     7499,
#     7631,
#     7752,
#     9367,
#     9524,
#     11172,
#     11295,
#     11392,
#     11636,
#     13017,
#     14300,
#     18761,
#     20575,
#     22892,
#     24723,
#     26779,
#     30519,
#     30793,
#     36564,
#     37016,
#     37339,
#     38099,
#     38650,
#     38729,
#     39084,
#     40277,
#     41630,
#     42818,
#     43239,
#     43378,
#     44421,
#     45804,
#     46362,
#     46586,
#     47049,
#     47946,
#     48059,
#     48266,
#     48554,
#     48722,
#     49700,
#     49974,
#     50179,
#     50344,
#     50624,
#     51344,
#     51644,
#     52395,
#     54726,
#     55134,
#     55311,
#     55430,
#     55845,
#     55973,
#     56160,
#     61313,
#     61858]],
#   ['pdf2text_op\\hs04jams.txt',
#    [1318,
#     9200,
#     9598,
#     19936,
#     20439,
#     20517,
#     20678,
#     20842,
#     32099,
#     34664,
#     35120,
#     40992,
#     41354,
#     42104,
#     42282,
#     47759,
#     54308,
#     54453,
#     57268]],
#   ['pdf2text_op\\hzz14pom.txt', [24520, 26742, 26993, 67342]],
#   ['pdf2text_op\\j07dissertation.txt', [275898]],
#   ['pdf2text_op\\jdrv13ijpr.txt',
#    [1988,
#     19946,
#     20173,
#     25783,
#     27030,
#     29097,
#     30633,
#     32238,
#     42995,
#     45787,
#     46501,
#     48413,
#     48511]],
#   ['pdf2text_op\\jxn11ijpr.txt',
#    [12842, 12981, 26358, 27412, 27765, 38333, 39013, 75006]],
#   ['pdf2text_op\\lhwh15ijlm.txt', [28988]],
#   ['pdf2text_op\\lwl14aijpe.txt',
#    [182,
#     1411,
#     1704,
#     1788,
#     1880,
#     1972,
#     7276,
#     7326,
#     8249,
#     8737,
#     9101,
#     9349,
#     9445,
#     17656,
#     23890,
#     24561,
#     25097,
#     25369,
#     25923,
#     26462,
#     27022,
#     27432,
#     27891,
#     27986,
#     28089,
#     28650,
#     28887,
#     29540,
#     29726,
#     34413,
#     36329,
#     37152,
#     39063,
#     40283,
#     43232,
#     43656,
#     43738,
#     43883,
#     44076,
#     44193,
#     45427,
#     45495,
#     45567,
#     46251,
#     46415,
#     46605,
#     46884,
#     47777,
#     47852,
#     48812,
#     50324,
#     50490,
#     50798,
#     51288,
#     52388,
#     53724,
#     54695,
#     57285]],
#   ['pdf2text_op\\lwl14bijpe.txt', [55224]],
#   ['pdf2text_op\\lwl14ijpe.txt',
#    [182,
#     1411,
#     1704,
#     1788,
#     1880,
#     1972,
#     7276,
#     7326,
#     8249,
#     8737,
#     9101,
#     9349,
#     9445,
#     17656,
#     23890,
#     24561,
#     25097,
#     25369,
#     25923,
#     26462,
#     27022,
#     27432,
#     27891,
#     27986,
#     28089,
#     28650,
#     28887,
#     29540,
#     29726,
#     34413,
#     36329,
#     37152,
#     39063,
#     40283,
#     43232,
#     43656,
#     43738,
#     43883,
#     44076,
#     44193,
#     45427,
#     45495,
#     45567,
#     46251,
#     46415,
#     46605,
#     46884,
#     47777,
#     47852,
#     48812,
#     50324,
#     50490,
#     50798,
#     51288,
#     52388,
#     53724,
#     54695,
#     57285]],
#   ['pdf2text_op\\ms09jom.txt', [11972]],
#   ['pdf2text_op\\nso13ijrm.txt', [964]],
#   ['pdf2text_op\\rbcc15jscm.txt',
#    [19819, 21230, 21277, 26256, 36943, 41519, 43157, 44465, 44939, 48638]],
#   ['pdf2text_op\\s14jpim.txt',
#    [4402,
#     5436,
#     5554,
#     5960,
#     9593,
#     17628,
#     28177,
#     38477,
#     46028,
#     51082,
#     51390,
#     54636,
#     56725,
#     57606,
#     59156,
#     65904,
#     70489,
#     82238]],
#   ['pdf2text_op\\slr13jpim.txt', [49391]],
#   ['pdf2text_op\\snk05dsj.txt', [68341]],
#   ['pdf2text_op\\snw07jom.txt',
#    [13645,
#     20378,
#     22846,
#     34830,
#     36565,
#     42762,
#     47343,
#     47867,
#     48292,
#     48516,
#     53350,
#     61887,
#     62567]],
#   ['pdf2text_op\\ss15jbl.txt', [44501, 44878, 56569, 80882, 87435]],
#   ['pdf2text_op\\sz13jpim.txt',
#    [1219,
#     13625,
#     30564,
#     30615,
#     31025,
#     35598,
#     35724,
#     35879,
#     36192,
#     36768,
#     36976,
#     37034,
#     44032,
#     44388,
#     48944,
#     49084,
#     50101,
#     50875,
#     51477,
#     51626,
#     52418,
#     52725,
#     82820]],
#   ['pdf2text_op\\tps12ds.txt', [10419, 12565, 23868, 25304, 26403, 39157]],
#   ['pdf2text_op\\wbw11jom.txt',
#    [1437,
#     5249,
#     10835,
#     11036,
#     12209,
#     15476,
#     17487,
#     20702,
#     21384,
#     23948,
#     29942,
#     35963,
#     39974,
#     40649,
#     40780,
#     40890,
#     42493,
#     42550,
#     42588,
#     42633,
#     42678,
#     44846,
#     44881,
#     44923,
#     44965,
#     51020,
#     51330,
#     51449,
#     51494,
#     51640,
#     51727,
#     51984,
#     52186,
#     53514,
#     53806,
#     56303,
#     57489,
#     57902,
#     66241]],
#   ['pdf2text_op\\wew07jbr.txt', [33236]],
#   ['pdf2text_op\\yjse13ijpe.txt',
#    [1621,
#     10264,
#     10958,
#     11254,
#     15593,
#     26167,
#     34130,
#     38662,
#     50510,
#     50980,
#     51057,
#     51166,
#     51365,
#     51951,
#     53306,
#     54258,
#     56941,
#     57451,
#     57526,
#     57672,
#     58957,
#     59078,
#     59574,
#     59888,
#     61197,
#     61475,
#     66470,
#     69324]],
#   ['pdf2text_op\\zgisc15jcp.txt', [48922]],
#   ['pdf2text_op\\zh13ijpdlm.txt',
#    [1094,
#     11429,
#     11669,
#     11841,
#     16060,
#     18483,
#     22093,
#     23191,
#     29357,
#     32603,
#     32728,
#     33677,
#     34680,
#     34912,
#     42135,
#     43152]]],
#  'brand equity': [['pdf2text_op\\bc15apjm.txt', [8740, 72370, 74174, 74947]],
#   ['pdf2text_op\\brp10jbe.txt', [1712]],
#   ['pdf2text_op\\cb07imm.txt', [50449, 50590, 53388, 54806, 55245]],
#   ['pdf2text_op\\cct10lodj.txt', [53914]],
#   ['pdf2text_op\\cd10imm.txt', [37919]],
#   ['pdf2text_op\\cg00job.txt', [3339, 49690, 67169]],
#   ['pdf2text_op\\cgl09jom.txt', [4760, 11864, 21397, 71120]],
#   ['pdf2text_op\\cs06amj.txt', [80400]],
#   ['pdf2text_op\\gfn12pfj.txt', [25220, 64806]],
#   ['pdf2text_op\\gj09jmr.txt', [83227]],
#   ['pdf2text_op\\haa10pjcss.txt', [5192, 21208, 25706]],
#   ['pdf2text_op\\hhm03discussionpaper.txt', [54074]],
#   ['pdf2text_op\\jdrv13ijpr.txt', [72558]],
#   ['pdf2text_op\\km05smj.txt', [6370]],
#   ['pdf2text_op\\kx09imm.txt', [7864, 63889, 65388]],
#   ['pdf2text_op\\lpaf13jcp.txt', [55488]],
#   ['pdf2text_op\\m06thesis.txt', [53085, 69433, 206457, 215993]],
#   ['pdf2text_op\\mn99jit.txt', [49939]],
#   ['pdf2text_op\\mrh10jbm.txt', [40451]],
#   ['pdf2text_op\\ng10crr.txt', [43018]],
#   ['pdf2text_op\\nl01jrcs.txt', [8494, 40969]],
#   ['pdf2text_op\\pf05jar.txt',
#    [449,
#     2386,
#     8818,
#     9026,
#     9184,
#     11612,
#     13565,
#     13671,
#     14102,
#     14477,
#     17236,
#     17348,
#     17480,
#     20631,
#     22056,
#     26487]],
#   ['pdf2text_op\\pwr09amj.txt', [80459]],
#   ['pdf2text_op\\s04csrem.txt', [6471]],
#   ['pdf2text_op\\sh10imm.txt', [32980, 46296]],
#   ['pdf2text_op\\skh06ejm.txt', [13376, 13572, 48668, 53847, 57125]],
#   ['pdf2text_op\\ss93ms.txt',
#    [40,
#     1101,
#     1256,
#     1328,
#     1712,
#     1774,
#     1847,
#     1917,
#     2043,
#     2152,
#     3360,
#     3559,
#     3888,
#     4229,
#     4346,
#     4737,
#     4798,
#     4871,
#     5152,
#     5607,
#     5693,
#     5839,
#     5930,
#     5983,
#     6352,
#     6395,
#     6452,
#     6675,
#     6750,
#     6823,
#     7115,
#     7491,
#     7816,
#     8474,
#     8811,
#     8895,
#     8930,
#     9229,
#     9381,
#     10260,
#     11549,
#     11656,
#     12177,
#     12842,
#     12975,
#     13333,
#     13387,
#     13517,
#     13871,
#     14308,
#     15206,
#     15662,
#     17323,
#     17441,
#     17553,
#     18872,
#     19391,
#     19731,
#     20127,
#     21476,
#     22467,
#     22542,
#     22623,
#     22996,
#     23114,
#     23238,
#     25364,
#     28788,
#     29845,
#     29933,
#     31467,
#     31625,
#     31857,
#     31999,
#     32523,
#     32816,
#     32969,
#     33195,
#     34065,
#     36318,
#     36481,
#     36624,
#     38325,
#     38382,
#     38499,
#     38600,
#     38943,
#     39264,
#     39924,
#     40102,
#     40220,
#     41694,
#     42102,
#     42411,
#     44076,
#     45671,
#     45727,
#     46409,
#     46516,
#     46554,
#     46604,
#     46672,
#     46751,
#     46824,
#     47329,
#     47836,
#     48091,
#     48152,
#     48242,
#     48392,
#     49414,
#     50372,
#     50682,
#     50746,
#     52100,
#     52245,
#     52599,
#     52872,
#     53047,
#     53297,
#     53657,
#     54130,
#     54568,
#     54673,
#     54786,
#     54910,
#     54985,
#     55314,
#     55442,
#     55594,
#     56486,
#     56735,
#     56811,
#     57510,
#     59158,
#     60671,
#     60859,
#     61049,
#     61649,
#     62694,
#     63190,
#     64599,
#     64729,
#     64808,
#     64945,
#     65191,
#     65292,
#     65375,
#     65619,
#     65682,
#     66334,
#     66402,
#     66516,
#     66802,
#     67071,
#     68238,
#     68417,
#     69010,
#     69290,
#     69501,
#     69661,
#     69972,
#     71733,
#     72169,
#     72240,
#     72524,
#     72675,
#     72767,
#     72953,
#     73061,
#     73143,
#     73407,
#     74122,
#     74589,
#     74802,
#     75035,
#     75076,
#     75158,
#     75262,
#     75859,
#     76098,
#     76300,
#     76402,
#     76712,
#     76984,
#     77098,
#     77285,
#     77772,
#     77848,
#     77935,
#     78118,
#     78235,
#     78430,
#     78536,
#     79878,
#     80444,
#     80833,
#     80971,
#     81217,
#     81369,
#     81725,
#     81814,
#     81952,
#     82317,
#     83225,
#     83553,
#     83746,
#     84297,
#     84992,
#     87898,
#     89149,
#     89694,
#     91233,
#     91324,
#     91607,
#     91756,
#     91986,
#     92697]],
#   ['pdf2text_op\\sz13jpim.txt', [64529, 72957]],
#   ['pdf2text_op\\tc03job.txt', [7128, 64036]],
#   ['pdf2text_op\\twy11jbe.txt', [53106]],
#   ['pdf2text_op\\vm09jbr.txt', [50986, 51377, 51413, 51527]],
#   ['pdf2text_op\\whpd10jbe.txt', [79065, 90193]],
#   ['pdf2text_op\\wlsl14bse.txt', [57062]],
#   ['pdf2text_op\\xp11jsm.txt', [40645]],
#   ['pdf2text_op\\zsl14apjm.txt', [63535, 64532]]],
#  'service level': [['pdf2text_op\\bc15apjm.txt', [29820]],
#   ['pdf2text_op\\cg05smj.txt', [10695]],
#   ['pdf2text_op\\hzz14pom.txt', [22826, 35594]],
#   ['pdf2text_op\\jdrv13ijpr.txt', [24434]],
#   ['pdf2text_op\\k99dissertation.txt', [39493, 39577, 39705]],
#   ['pdf2text_op\\nsrsa13apjml.txt', [19899]],
#   ['pdf2text_op\\s01dissertation.txt', [75207]],
#   ['pdf2text_op\\sc00ijsim.txt', [13716, 34288]],
#   ['pdf2text_op\\ss15jbl.txt', [27211]],
#   ['pdf2text_op\\vgr09dsj.txt', [29636, 43089]],
#   ['pdf2text_op\\yjse13ijpe.txt', [18684]],
#   ['pdf2text_op\\yzpl13ijpe.txt', [49375]]],
#  'market growth rate': [['pdf2text_op\\bgd05jom.txt', [19608]],
#   ['pdf2text_op\\g98smj.txt', [45096]]],
#  'servqual': [['pdf2text_op\\bnk00jbr.txt', [25367]],
#   ['pdf2text_op\\ce10jbr.txt', [13521, 33940, 45612]],
#   ['pdf2text_op\\dvdunpublishedmanuscript.txt',
#    [11535,
#     95974,
#     99042,
#     131737,
#     131927,
#     132190,
#     132762,
#     132847,
#     139471,
#     290326,
#     291559,
#     292893,
#     296379,
#     296407,
#     296438,
#     296472,
#     296500,
#     306258,
#     323086,
#     329072,
#     329818,
#     330119,
#     345711,
#     345897,
#     357196,
#     372988,
#     373270]],
#   ['pdf2text_op\\em05jom.txt', [60162]],
#   ['pdf2text_op\\g00dissertation.txt',
#    [83426,
#     85308,
#     103431,
#     108863,
#     109153,
#     112895,
#     113076,
#     119172,
#     119371,
#     119518,
#     126936,
#     138915,
#     152713]],
#   ['pdf2text_op\\hf96jom.txt',
#    [47898, 48028, 48308, 48596, 49075, 76329, 96114, 97361]],
#   ['pdf2text_op\\itlh09jap.txt', [90587, 101126]],
#   ['pdf2text_op\\j11sij.txt', [35854]],
#   ['pdf2text_op\\kx09imm.txt', [15129]],
#   ['pdf2text_op\\lk11ijhm.txt', [12161, 12839, 21601, 47208, 52464, 52678]],
#   ['pdf2text_op\\s01dissertation.txt',
#    [93841, 94167, 94605, 95014, 95118, 179211, 191389]],
#   ['pdf2text_op\\wb07jams.txt', [24951, 60952, 80215]],
#   ['pdf2text_op\\wbs09ajbr.txt', [36008]],
#   ['pdf2text_op\\y07tqm.txt', [15141, 44762]],
#   ['pdf2text_op\\y07tqmbe.txt', [15141, 44762]],
#   ['pdf2text_op\\ys03jbr.txt', [11438, 38417, 38582, 69425, 74300, 74634]]],
#  'customer engagement': [['pdf2text_op\\c12dissertation.txt',
#    [245256, 246890]],
#   ['pdf2text_op\\s08dissertation.txt',
#    [16162,
#     17443,
#     71610,
#     92231,
#     149091,
#     333326,
#     333906,
#     336555,
#     339245,
#     344437,
#     353369,
#     391014,
#     391540,
#     403456,
#     466388,
#     492724,
#     512592,
#     577623,
#     578996]],
#   ['pdf2text_op\\slr13jpim.txt', [51514]],
#   ['pdf2text_op\\z03ohioedu.txt', [234637]]],
#  'customer lifetime value': [['pdf2text_op\\cb07imm.txt', [60988]],
#   ['pdf2text_op\\j11sij.txt', [1437]]],
#  'customer support': [['pdf2text_op\\CHINA wq11amj.txt', [15574]],
#   ['pdf2text_op\\fpe08jams.txt', [48179]],
#   ['pdf2text_op\\j07dissertation.txt', [271948]],
#   ['pdf2text_op\\lwl14aijpe.txt', [26943]],
#   ['pdf2text_op\\lwl14bijpe.txt', [10211]],
#   ['pdf2text_op\\lwl14ijpe.txt', [26943]],
#   ['pdf2text_op\\s08dissertation.txt', [427693]],
#   ['pdf2text_op\\s98dissertation.txt', [366593]],
#   ['pdf2text_op\\wlsl14bse.txt', [15804]],
#   ['pdf2text_op\\wq11amj.txt', [15577]]],
#  'customer experience': [['pdf2text_op\\cl10pp.txt', [6760, 6992, 28849]],
#   ['pdf2text_op\\g00dissertation.txt', [174401, 177341]],
#   ['pdf2text_op\\kavsc06amj.txt', [37057]],
#   ['pdf2text_op\\m94dissertation.txt',
#    [24575, 28336, 120899, 170047, 212556, 245882, 272208]],
#   ['pdf2text_op\\mrh10jbm.txt', [10597, 20387, 20507]],
#   ['pdf2text_op\\nl01jrcs.txt', [12552]],
#   ['pdf2text_op\\sc00ijsim.txt', [16299, 17977, 30892, 40575]],
#   ['pdf2text_op\\wwy13jbbm.txt', [8202]]],
#  'customer retention rate': [['pdf2text_op\\jdrv13ijpr.txt', [91137]]]}

# %%
import pandas as pd
kpis.insert(0,'pdf_name')
df = pd.DataFrame(columns = [x.lower() for x in kpis])

# %%
df =df.set_index('pdf_name')

# %%
df
# Out:
# Empty DataFrame
# Columns: [net promoter score, customer retention rate, customer profitability, customer lifetime value, customer turnover rate, customer engagement, servqual, customer complaint, market share, market growth rate, brand equity, conversion rate, customer online engagement, online share of voice, social networking footprint, klout score, corporate reputation, difot rate, customer satisfaction, customer experience, customer loyalty, brand attributes, customer support, first contact resolution, customer attraction, customer callback, customer focus, service level, customer effort score, support cost, average response time, complaint escalation rate, customer integration]
# Index: []
#
# [0 rows x 33 columns]

# %%
df
# Out:
#             net promoter score customer retention rate customer profitability  \
# pdf_name
# 3                          NaN                     NaN                    NaN
# ys03jbr.txt                  1                     NaN                    NaN
#
#             customer lifetime value customer turnover rate  \
# pdf_name
# 3                               NaN                    NaN
# ys03jbr.txt                     NaN                    NaN
#
#             customer engagement servqual customer complaint market share  \
# pdf_name
# 3                           NaN      NaN                NaN          NaN
# ys03jbr.txt                 NaN      NaN                NaN          NaN
#
#             market growth rate     ...      customer attraction  \
# pdf_name                           ...
# 3                          NaN     ...                      NaN
# ys03jbr.txt                NaN     ...                      NaN
#
#             customer callback customer focus service level  \
# pdf_name
# 3                         NaN            NaN           NaN
# ys03jbr.txt               NaN            NaN           NaN
#
#             customer effort score support cost average response time  \
# pdf_name
# 3                             NaN          NaN                   NaN
# ys03jbr.txt                   NaN          NaN                   NaN
#
#             complaint escalation rate customer integration     pdf_name
# pdf_name
# 3                                 NaN                  NaN  ys03jbr.txt
# ys03jbr.txt                       NaN                  NaN          NaN
#
# [2 rows x 34 columns]

# %%
import pdb
import numpy as np
for (kpi_column, pdf_names) in kpi_text.items():
    for pdf_name in pdf_names:
        pdf_name,count_words = pdf_name[0],pdf_name[1]
        pdf_name = pdf_name.split("\\")[-1]
        if pdf_name in df.index :
            if np.isnan(df.loc[pdf_name,kpi_column]): 
                df.loc[pdf_name,kpi_column] = len(count_words)
            else:
                df.loc[pdf_name,kpi_column] = df.loc[pdf_name,kpi_column] + len(count_words)
        else :
            row = pd.Series({kpi_column: len(count_words)},name=pdf_name)
            df =df.append(row)

# %%
df.to_csv('final_list.csv')

# %%
df.loc['clrv04ar.txt',:]
# Out:
# net promoter score             NaN
# customer retention rate        NaN
# customer profitability         NaN
# customer lifetime value        NaN
# customer turnover rate         NaN
# customer engagement            NaN
# servqual                       NaN
# customer complaint             NaN
# market share                   NaN
# market growth rate             NaN
# brand equity                   NaN
# conversion rate                NaN
# customer online engagement     NaN
# online share of voice          NaN
# social networking footprint    NaN
# klout score                    NaN
# corporate reputation           NaN
# difot rate                     NaN
# customer satisfaction          2.0
# customer experience            NaN
# customer loyalty               NaN
# brand attributes               NaN
# customer support               NaN
# first contact resolution       NaN
# customer attraction            NaN
# customer callback              NaN
# customer focus                 NaN
# service level                  NaN
# customer effort score          NaN
# support cost                   NaN
# average response time          NaN
# complaint escalation rate      NaN
# customer integration           NaN
# Name: clrv04ar.txt, dtype: float64

# %%
article_text_file = open("abs1Text/Text/sgd05amj.txt","r")
article_text = article_text_file.read()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-c09a5395b4bf> in <module>()
# ----> 1 article_text_file = open("abs1Text/Text/sgd05amj.txt","r")
#       2 article_text = article_text_file.read()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'abs1Text/Text/sgd05amj.txt'

# %%
article_text_file = open("abs1Text/Text/sgd05amj.txt","r")
article_text = article_text_file.read()
print(summarize_article(article_text))
# Out:
# The relationship between vol- untary turnover and workforce performance is curvilinear: it is positive as voluntary turnover increases initially but becomes negative as turnover further increases. Voluntary turnover affects workforce performance negatively by diminishing firm-specific human capital accumulations, but these losses are less severe, and their performance effects are ameliorated at high levels of turnover. We investigated whether workforce performance mediated the relationship of voluntary turnover and financial performance in Study 2 with two measures of financial performance: operating ratio and return on equity. The results consis- tently support a curvilinear pattern in which the effects of turnover on workforce performance are very strong when turnover is low but weaken as turnover increases. Although the general effects of voluntary turnover on workforce performance are considered negative, these authors detail the bene- fits of some minimum level of turnover for such performance. In two intraindustry studies, strong support emerged for curvilinearity: the relationship between voluntary turnover and workforce performance is negative, but it is attenuated as turnover increases. That is, the relationship between voluntary turnover and accident rate in this sample diminishes as turnover increases and falls to a zero slope at a turnover of 57 percent.

# %%
article_text_file = open("abs1Text/Text/w02jom.txt","r")
article_text = article_text_file.read()
print(summarize_article(article_text))
# Out:
# Journal of Management 2002 28(6) 765–785 High Performance Work Systems and Intermediate Indicators of Firm Performance Within the US Small Business Sector ∗ Sean A. Formal training can have a positive impact on employee skills, employee behavior scripts, employee motivation, employee output, and ﬁrm performance (see Blanchard & Thacker, 1999; Kirkpatrick, 1998). Thus, within the US small business sector gaining access to a workforce that produces superior employee output is a source of sustainable competitive advantage. Thus, pay level (a component of this study’s HPWS) may enhance the ﬁrm’s ability to gain access to a workforce that produces superior employee output. Thus voluntary turnover may be of greater importance than workforce turnover within the US small business sector. High Performance Work Systems and Intermediate Indicators of Firm Performance Workforce turnover. Within the US small business sector it is expected that there will be a negative relationship between the use of HPWS and workforce turnover.

# %%
article_text_file = open("abs1Text/Text/mo05jbr.txt","r")
article_text = article_text_file.read()
print(summarize_article(article_text))
# Out:
# These performance measures were selected because they capture both firm market performance (market share) and financial performance (sales growth and profit after tax). Keywords: Natural environmental orientation; Corporate social responsibility; Entrepreneurship; Environmental commitment; Resource-based view 1. For instance, external and internal reporting, environmental audits and reviews, internal environmental reward systems, and employee training are included in the measure of environmental commitment. Specifically: to firms, Hypothesis 1: NEO is a higher order construct composed of three dimensions: (a) entrepreneurship, (b) CSR, and (c) environmental commitment. Effective communi- cation of the environmental impact of the products is likely to positively affect a firm’s performance through its reputational advantage (Miles and Covin, 2000). Based on the literature in this area, the authors define NEO as comprising three components: entrepreneurship, corporate social responsibility (CSR), and commitment to the natural environment. As previously mentioned, this study is the first to explic- itly test Hart’s (1995) theory of a competitive advantage based upon the firm’s relationship to the natural environment.

# %%
article_text_file = open("abs1Text/Text/a94amj.txt","r")
article_text = article_text_file.read()
print(summarize_article(article_text))
# Out:
# technology Hypothesis 1: Plants with commitment human resource systems will have better manufacturing performance than plants with control human resource systems. Hypothesis 2: Turnover will be higher in control human resource systems than in commitment human resource systems. THEORETICAL DEVELOPMENT AND HYPOTHESES Testing the strategic human resource perspective first requires catego- rizing organizations into a meaningful typology of human resource systems. Finally, Hypothesis 3 states that the negative relationship between turn- over and manufacturing performance will be higher in commitment human resource systems than in control systems. Further, research progress on the human resource strategy perspective depends critically on the development of conceptually and methodologi- cally sound measures of the human resource system construct. In contrast, commitment human resource systems shape desired employee behaviors and attitudes by forging psychological links between organizational and employee goals. In addition, the study has shown that identification of human resource systems promises to add significantly to understanding the relationship between turnover and organizational performance.

# %%
article_text_file = open("abs1Text/Text/th08os.txt","r")
article_text = article_text_file.read()
print(summarize_article(article_text))
# Out:
# s ( r o h t u a e h t o t y s e t r u o c . s m r o f n i . / g r o . Finally, we ﬁnd that, at high-process-conformance stores, turnover does not decrease store performance, whereas at low- process-conformance stores, turnover does decrease store performance. We ﬁnd that increasing turnover does not have a negative effect on store performance at high-process-conformance stores; at low-process-conformance stores, the negative effect of turnover is pronounced. To make sure that turnover is not endogenous to per- formance, we asked store managers, store employees, and corporate managers what drives turnover at Borders stores. Percent of full-time employees Total payroll (in ten thousands) Number of local competitors Percent of local unemployment Store ﬁxed effects?

# %%
article_text_file = open("abs1Text/Text/tr93pp.txt","r")
article_text = article_text_file.read()
print(summarize_article(article_text))
# Out:
# d e r e t n e s a w s e ) e 9 y - 8 o l = p m n e ( f . y l e v i t c e p s e r , 0 2 - 6 1 d n a . o c i e n l u b m a i r m a v o l c o / r . D S l g n i n i M n o i t c u r t s n o C M D S . - n o i s s e r g e R . l l . Correlational analy- ses conducted by individual staffing practices revealed that the number of employees was significantly related with two of the five staffing practices.

# %%
article_text_file = open("abs1Text/Text/k03jom.txt","r")
article_text = article_text_file.read()
print(summarize_article(article_text))
# Out:
# Management leadership is directly related to training, employee relations, supplier quality management, and prod- uct design, and indirectly related to quality data and reporting, and process management. The positive effect of quality data and reporting on ﬁrm performance is through three other TQM techniques: supplier quality management, product/service design, and process management. Management leadership, train- ing, employee relations, and quality data and reporting affect operating performance through supplier qual- ity management, product/service design, and process management. It is also important that they recognize the indirect positive effects of supplier quality management on quality performance, and ﬁ- nancial and market performance. Supplier quality management Effective supplier quality management is facilitated by long-term, cooperative relationships with as few suppliers as possible to obtain quality materials and/or services. Perceived performance (subjective) Operating performance Product quality Questionnaire Hierarchical regression analysis Supportive TQM factor has an indirect effect on product quality through core TQM factor. Supplier quality management emerges as an impor- tant component of TQM, directly and positively affect- ing product/service design, process management, and inventory management performance.

# %%
article_text_file = open("abs1Text/Text/tbbc09halmstaduniversity.txt","r")
article_text = article_text_file.read()
print(summarize_article(article_text))
# Out:
# The same variables that explain the extent of social disclosures also seem to explain the content of such disclosures on corporate websites. Public awareness and interest in social, environmental and ethical issues and increased attention in mass media have resulted in more corporations making social disclosures about themselves (e.g. Management that has the knowledge to make a company profitable also has the knowledge and understanding of social responsibility, which leads to more social and environmental disclosures. One explanation for not disclosing much social information in particular could be that no debate on social issues seems to prevail among these corporations. However, there are also other information channels that corporations use to communicate social and environmental information. The aim of this study is to explain the extent and content of social disclosure information on corporations’ websites. Corporate social responsibility in the mining industry: Exploring trends in social and environmental disclosure.

# %%
article_text_file = open("abs1Text/Text/gp01bjir.txt","r")
article_text = article_text_file.read()
print(summarize_article(article_text))
# Out:
# These three measures of engagement in partnership, employee commitment and employee contribution, while ostensibly employer measures, could also be construed as relevant outcomes from an employee perspective. The government has since further reinforced its concrete support for partnership by setting up a Partnership Fund to stimulate a diverse range of partnership activities and initiatives. Development and Measurement of Partnership Practices A review of the literature again revealed no specific measure of partnership practices. If the principles reflect some underlying concept of partnership, then we would expect them to receive a stronger endorsement in those organizations that have made more progress towards partnership. Analysing the Outcomes of Partnership A core assumption is that partnership brings benefits to the partners in terms of the outcomes of interest to the partners. Development and Measurement of Outcomes In most analyses of partnership at work, the key partners are normally considered to be managers, employees and employee representatives. Development and Measurement of Principles of Partnership A survey of the literature revealed no prior measures of principles of partnership.

# %%
article_text_file = open("abs1Text/Text/jy11bjir.txt","r")
article_text = article_text_file.read()
print(summarize_article(article_text))
# Out:
# t n e m e g a n a m e c r u o s e r . 0 < p e t a c i d n i r e t a e r g r o | 8 0 . 0 | = s n o i t a l e r r o C . d e t r o p e r 4 3 4 . d e t r o p e r 7 7 . 1 5 2 = N e s a c n i ( 0 1 . In Model 3, we ﬁnd that outsourced call centres pay their CSRs and managers signiﬁcantly less cash pay than in-house call centres.

# %%
article_text_file = open("abs1Text/Text/kyr11ijsom.txt","r")
article_text = article_text_file.read()
print(summarize_article(article_text))
# Out:
# Information sharing was classified to risk information sharing and product information sharing, and performance was differentiated to customer service performance, operational effectiveness, and financial performance. Kim et al. Few studies have differentiated risk Green Supply Chain Management orientation 285 information sharing from general information sharing and investigated their differing roles. This paper defines green management orientation in a supply chain context and examines its impact on firm performance that is mediated by trust and information sharing. This study, based on 125 companies from South Korea, shows that GSCM orientation positively influences firm performance via supply chain partners’ trust and information sharing. H6: Product information sharing with supply chain partners is positively related to (a) customer service performance, (b) operational effectiveness, and (c) financial performance. Therefore, H5: Risk information sharing with supply chain partners is positively related to (a) customer service performance, (b) operational effectiveness, and (c) financial performance.
